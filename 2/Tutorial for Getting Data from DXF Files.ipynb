# %% [markdown]
# 本教程介绍如何使用ezdxf库从现有的DXF文档中获取数据。如果您是ezdxf的新用户，请先阅读“入门用法”教程。
#
# 加载DXF文件：

# %%
import sys
import ezdxf

try:
    doc = ezdxf.readfile("test.dxf")
except IOError:
    print(f"不是DXF文件或者存在I/O错误。")
    sys.exit(1)
except ezdxf.DXFStructureError:
    print(f"DXF文件无效或损坏。")
    sys.exit(2)

# %% [markdown]
# 这对于来自AutoCAD或BricsCAD等可信来源的DXF文件很好用，对于存在较小或较大缺陷的DXF文件，可以查看`ezdxf.recover`模块。

# %% [markdown]
# ### 布局
#
# 术语“布局”用作与任意实体空间的同义词，该空间可以包含DXF实体，如线、圆、文本等。每个DXF实体只能驻留在一个确切的布局中。
#
# 有三种不同的布局类型：
#
# - 模型空间(modelspace)：常见的构建空间
# - 纸张空间(paperspace)：用于创建打印布局
# - 块布局(block)：可重复使用的元素，每个块都有自己的实体空间
#
# 一个DXF文档包括一个确切的模型空间和至少一个纸张空间。 DXF R12只有一个未命名的纸张空间，后来的DXF版本支持多个纸张空间，每个纸张空间都有一个名称。
#
# ### 获取模型空间布局
#
# 模型空间包含以真实世界单位表示的绘图主题的“真实”世界表示。模型空间的固定名称为“Model”，DXF文档具有特殊的getter方法`modelspace()`。

# %%
msp = doc.modelspace()

# %% [markdown]
# ### 迭代布局中的DXF实体
#
# 此代码展示了如何迭代模型空间中的所有DXF实体：

# %%
# 帮助函数
def print_entity(e):
    print("LINE on layer: %s\n" % e.dxf.layer)
    print("start point: %s\n" % e.dxf.start)
    print("end point: %s\n" % e.dxf.end)

# 遍历模型空间中的所有实体
msp = doc.modelspace()
for e in msp:
    if e.dxftype() == "LINE":
        print_entity(e)

# 查询模型空间中所有LINE实体
for e in msp.query("LINE"):
    print_entity(e)
# Out:
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 222.3204968081464, 0.0)
#
# end point: (217.4625698753752, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 222.3204968081464, 0.0)
#
# end point: (211.3825698753752, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (213.8145698753751, 221.1044968081464, 0.0)
#
# end point: (213.8145698753751, 213.8084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 212.5924968081464, 0.0)
#
# end point: (217.4625698753752, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 212.5924968081464, 0.0)
#
# end point: (211.3825698753752, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 122.6084968081464, 0.0)
#
# end point: (217.4625698753752, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 122.6084968081464, 0.0)
#
# end point: (211.3825698753752, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (213.8145698753751, 121.3924968081464, 0.0)
#
# end point: (213.8145698753751, 114.0964968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 112.8804968081464, 0.0)
#
# end point: (217.4625698753752, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 112.8804968081464, 0.0)
#
# end point: (211.3825698753752, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 108.0164968081464, 0.0)
#
# end point: (39.92656987537512, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 108.0164968081464, 0.0)
#
# end point: (148.1505698753751, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 106.8004968081464, 0.0)
#
# end point: (50.87056987537514, 104.3684968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 173.6804968081464, 0.0)
#
# end point: (55.73456987537511, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 174.8964968081464, 0.0)
#
# end point: (50.87056987537514, 221.1044968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 172.4644968081464, 0.0)
#
# end point: (50.87056987537514, 160.3044968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 227.1844968081464, 0.0)
#
# end point: (38.71056987537514, 227.1844968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 227.1844968081464, 0.0)
#
# end point: (36.27856987537513, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 222.3204968081464, 0.0)
#
# end point: (38.25456987537513, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 112.8804968081464, 0.0)
#
# end point: (38.71056987537514, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 112.8804968081464, 0.0)
#
# end point: (36.27856987537513, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 108.0164968081464, 0.0)
#
# end point: (38.25456987537513, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (165.1745698753751, 217.4564968081464, 0.0)
#
# end point: (167.6065698753751, 217.4564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (165.1745698753751, 217.4564968081464, 0.0)
#
# end point: (165.1745698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (174.9025698753751, 217.4564968081464, 0.0)
#
# end point: (172.4705698753751, 217.4564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (174.9025698753751, 217.4564968081464, 0.0)
#
# end point: (174.9025698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (165.1745698753751, 212.5924968081464, 0.0)
#
# end point: (161.5265698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (166.3905698753751, 212.5924968081464, 0.0)
#
# end point: (167.6065698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (174.9025698753751, 212.5924968081464, 0.0)
#
# end point: (172.4705698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 212.5924968081464, 0.0)
#
# end point: (177.3345698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 212.5924968081464, 0.0)
#
# end point: (177.3345698753751, 198.0004968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (178.5505698753751, 212.5924968081464, 0.0)
#
# end point: (180.9825698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (179.7665698753751, 193.1364968081464, 0.0)
#
# end point: (182.1985698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (179.7665698753751, 193.1364968081464, 0.0)
#
# end point: (179.7665698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 193.1364968081464, 0.0)
#
# end point: (187.0625698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 193.1364968081464, 0.0)
#
# end point: (189.4945698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (179.7665698753751, 188.2724968081464, 0.0)
#
# end point: (178.5505698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (180.9825698753751, 188.2724968081464, 0.0)
#
# end point: (182.1985698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 188.2724968081464, 0.0)
#
# end point: (187.0625698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (204.0865698753752, 188.2724968081464, 0.0)
#
# end point: (200.4385698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (204.0865698753752, 188.2724968081464, 0.0)
#
# end point: (204.0865698753752, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (204.0865698753752, 171.2484968081464, 0.0)
#
# end point: (204.0865698753752, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (204.0865698753752, 171.2484968081464, 0.0)
#
# end point: (204.0865698753752, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (202.8705698753751, 171.2484968081464, 0.0)
#
# end point: (195.5745698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (202.8705698753751, 173.6804968081464, 0.0)
#
# end point: (195.5745698753751, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 112.8804968081464, 0.0)
#
# end point: (166.3905698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 112.8804968081464, 0.0)
#
# end point: (160.3105698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 122.6084968081464, 0.0)
#
# end point: (160.3105698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (161.5265698753751, 122.6084968081464, 0.0)
#
# end point: (165.1745698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 222.3204968081464, 0.0)
#
# end point: (166.3905698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (160.3105698753751, 222.3204968081464, 0.0)
#
# end point: (149.3665698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 221.1044968081464, 0.0)
#
# end point: (160.3105698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 122.6084968081464, 0.0)
#
# end point: (177.3345698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 122.6084968081464, 0.0)
#
# end point: (170.0385698753752, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (178.5505698753751, 122.6084968081464, 0.0)
#
# end point: (180.9825698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 173.6804968081464, 0.0)
#
# end point: (180.9825698753751, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 173.6804968081464, 0.0)
#
# end point: (177.3345698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 212.5924968081464, 0.0)
#
# end point: (189.4945698753751, 207.7284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 212.5924968081464, 0.0)
#
# end point: (185.8465698753752, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (190.7105698753751, 212.5924968081464, 0.0)
#
# end point: (191.9265698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 207.7284968081464, 0.0)
#
# end point: (210.1665698753751, 207.7284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 132.3364968081464, 0.0)
#
# end point: (177.3345698753751, 149.3604968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 132.3364968081464, 0.0)
#
# end point: (167.6065698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (177.3345698753751, 188.2724968081464, 0.0)
#
# end point: (177.3345698753751, 195.5684968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (176.1185698753751, 188.2724968081464, 0.0)
#
# end point: (149.3665698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 171.2484968081464, 0.0)
#
# end point: (180.9825698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 171.2484968081464, 0.0)
#
# end point: (177.3345698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 159.0884968081464, 0.0)
#
# end point: (177.3345698753751, 151.7924968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (176.1185698753751, 159.0884968081464, 0.0)
#
# end point: (149.3665698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (204.0865698753752, 108.0164968081464, 0.0)
#
# end point: (149.3665698753751, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 222.3204968081464, 0.0)
#
# end point: (39.92656987537512, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 222.3204968081464, 0.0)
#
# end point: (148.1505698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (106.8065698753752, 171.2484968081464, 0.0)
#
# end point: (109.2385698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (106.8065698753752, 171.2484968081464, 0.0)
#
# end point: (106.8065698753752, 172.4644968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (106.8065698753752, 176.1124968081464, 0.0)
#
# end point: (109.2385698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (106.8065698753752, 176.1124968081464, 0.0)
#
# end point: (106.8065698753752, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (106.8065698753752, 173.6804968081464, 0.0)
#
# end point: (100.7265698753751, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (92.21456987537512, 188.2724968081464, 0.0)
#
# end point: (111.6705698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (92.21456987537512, 188.2724968081464, 0.0)
#
# end point: (92.21456987537512, 160.3044968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (92.21456987537512, 159.0884968081464, 0.0)
#
# end point: (80.05456987537514, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (92.21456987537512, 159.0884968081464, 0.0)
#
# end point: (111.6705698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 188.2724968081464, 0.0)
#
# end point: (129.9105698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 188.2724968081464, 0.0)
#
# end point: (148.1505698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 189.4884968081464, 0.0)
#
# end point: (143.2865698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 187.0564968081464, 0.0)
#
# end point: (143.2865698753751, 183.4084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 176.1124968081464, 0.0)
#
# end point: (121.3985698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 176.1124968081464, 0.0)
#
# end point: (143.2865698753751, 182.1924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 183.4084968081464, 0.0)
#
# end point: (129.9105698753751, 183.4084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 146.9284968081464, 0.0)
#
# end point: (137.8145698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 146.9284968081464, 0.0)
#
# end point: (143.2865698753751, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 139.6324968081464, 0.0)
#
# end point: (129.9105698753751, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 138.4164968081464, 0.0)
#
# end point: (143.2865698753751, 133.5524968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 132.3364968081464, 0.0)
#
# end point: (129.9105698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 132.3364968081464, 0.0)
#
# end point: (148.1505698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 171.2484968081464, 0.0)
#
# end point: (121.3985698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 171.2484968081464, 0.0)
#
# end point: (143.2865698753751, 163.9524968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 163.9524968081464, 0.0)
#
# end point: (129.9105698753751, 163.9524968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 162.7364968081464, 0.0)
#
# end point: (143.2865698753751, 160.3044968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 159.0884968081464, 0.0)
#
# end point: (129.9105698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 159.0884968081464, 0.0)
#
# end point: (148.1505698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 159.0884968081464, 0.0)
#
# end point: (39.92656987537512, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 159.0884968081464, 0.0)
#
# end point: (54.51856987537514, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 157.8724968081464, 0.0)
#
# end point: (50.87056987537514, 148.1444968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (143.2865698753751, 193.1364968081464, 0.0)
#
# end point: (129.9105698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 146.9284968081464, 0.0)
#
# end point: (39.92656987537512, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 146.9284968081464, 0.0)
#
# end point: (99.5105698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 145.7124968081464, 0.0)
#
# end point: (50.87056987537514, 140.8484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 139.6324968081464, 0.0)
#
# end point: (39.92656987537512, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 139.6324968081464, 0.0)
#
# end point: (55.73456987537511, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 98.2884968081464, 0.0)
#
# end point: (39.92656987537512, 98.2884968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 99.50449680814641, 0.0)
#
# end point: (50.87056987537514, 101.9364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (210.1665698753751, 222.3204968081464, 0.0)
#
# end point: (194.3585698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (149.3665698753751, 132.3364968081464, 0.0)
#
# end point: (165.1745698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (210.1665698753751, 212.5924968081464, 0.0)
#
# end point: (196.7905698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (210.1665698753751, 122.6084968081464, 0.0)
#
# end point: (185.8465698753752, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (210.1665698753751, 112.8804968081464, 0.0)
#
# end point: (191.9265698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (171.2545698753751, 222.3204968081464, 0.0)
#
# end point: (173.6865698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (178.5505698753751, 222.3204968081464, 0.0)
#
# end point: (181.590569875375, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (185.2385698753751, 222.3204968081464, 0.0)
#
# end point: (189.4945698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (196.7905698753751, 188.2724968081464, 0.0)
#
# end point: (195.5745698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (191.9265698753751, 173.6804968081464, 0.0)
#
# end point: (185.8465698753752, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (191.9265698753751, 171.2484968081464, 0.0)
#
# end point: (185.8465698753752, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (171.2545698753751, 112.8804968081464, 0.0)
#
# end point: (173.6865698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (178.5505698753751, 112.8804968081464, 0.0)
#
# end point: (181.590569875375, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (185.2385698753751, 112.8804968081464, 0.0)
#
# end point: (187.0625698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (211.3825698753752, 207.7284968081464, 0.0)
#
# end point: (217.4625698753752, 207.7284968081464, 0.0)
#
# LINE on layer: EPLAN542
#
# start point: (130.5185698753751, 146.9284968081464, 0.0)
#
# end point: (121.3985698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (128.2385698753751, 188.2724968081464, 0.0)
#
# end point: (116.5345698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (60.59856987537514, 173.6804968081464, 0.0)
#
# end point: (73.97456987537515, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (66.67856987537516, 159.0884968081464, 0.0)
#
# end point: (75.1905698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN542
#
# start point: (65.00656987537506, 159.0884968081464, 0.0)
#
# end point: (61.81456987537512, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (81.27056987537512, 173.6804968081464, 0.0)
#
# end point: (99.5105698753751, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (120.1825698753752, 176.1124968081464, 0.0)
#
# end point: (114.1025698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (120.1825698753752, 171.2484968081464, 0.0)
#
# end point: (114.1025698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (116.5345698753751, 159.0884968081464, 0.0)
#
# end point: (128.2385698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (120.1825698753752, 146.9284968081464, 0.0)
#
# end point: (112.8865698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN510
#
# start point: (100.7265698753751, 146.9284968081464, 0.0)
#
# end point: (108.0225698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (212.5985698753752, 222.3204968081464, 0.0)
#
# end point: (215.0305698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 221.1044968081464, 0.0)
#
# end point: (215.0305698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 213.8084968081464, 0.0)
#
# end point: (215.0305698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (212.5985698753752, 212.5924968081464, 0.0)
#
# end point: (215.0305698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (212.5985698753752, 122.6084968081464, 0.0)
#
# end point: (215.0305698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 121.3924968081464, 0.0)
#
# end point: (215.0305698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.8145698753751, 114.0964968081464, 0.0)
#
# end point: (215.0305698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (212.5985698753752, 112.8804968081464, 0.0)
#
# end point: (215.0305698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 108.0164968081464, 0.0)
#
# end point: (52.08656987537512, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 108.0164968081464, 0.0)
#
# end point: (50.87056987537514, 106.8004968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 173.6804968081464, 0.0)
#
# end point: (52.08656987537512, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 173.6804968081464, 0.0)
#
# end point: (50.87056987537514, 174.8964968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 173.6804968081464, 0.0)
#
# end point: (50.87056987537514, 172.4644968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (37.49456987537513, 227.1844968081464, 0.0)
#
# end point: (36.27856987537513, 227.1844968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 227.1844968081464, 0.0)
#
# end point: (36.27856987537513, 225.9684968081465, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 223.5364968081464, 0.0)
#
# end point: (36.27856987537513, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 222.3204968081464, 0.0)
#
# end point: (37.49456987537513, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (37.49456987537513, 112.8804968081464, 0.0)
#
# end point: (36.27856987537513, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 112.8804968081464, 0.0)
#
# end point: (36.27856987537513, 111.6644968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 109.2324968081464, 0.0)
#
# end point: (36.27856987537513, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (36.27856987537513, 108.0164968081464, 0.0)
#
# end point: (37.49456987537513, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (166.3905698753751, 217.4564968081464, 0.0)
#
# end point: (165.1745698753751, 217.4564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (165.1745698753751, 217.4564968081464, 0.0)
#
# end point: (165.1745698753751, 216.2404968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (173.6865698753751, 217.4564968081464, 0.0)
#
# end point: (174.9025698753751, 217.4564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (174.9025698753751, 217.4564968081464, 0.0)
#
# end point: (174.9025698753751, 216.2404968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (165.1745698753751, 213.8084968081464, 0.0)
#
# end point: (165.1745698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (163.9585698753751, 212.5924968081464, 0.0)
#
# end point: (166.3905698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (174.9025698753751, 213.8084968081464, 0.0)
#
# end point: (174.9025698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (173.6865698753751, 212.5924968081464, 0.0)
#
# end point: (176.1185698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 212.5924968081464, 0.0)
#
# end point: (178.5505698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 212.5924968081464, 0.0)
#
# end point: (177.3345698753751, 211.3764968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (180.9825698753751, 193.1364968081464, 0.0)
#
# end point: (179.7665698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (179.7665698753751, 193.1364968081464, 0.0)
#
# end point: (179.7665698753751, 191.9204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (188.2785698753752, 193.1364968081464, 0.0)
#
# end point: (189.4945698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 193.1364968081464, 0.0)
#
# end point: (189.4945698753751, 191.9204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (179.7665698753751, 189.4884968081464, 0.0)
#
# end point: (179.7665698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (178.5505698753751, 188.2724968081464, 0.0)
#
# end point: (180.9825698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 189.4884968081464, 0.0)
#
# end point: (189.4945698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (188.2785698753752, 188.2724968081464, 0.0)
#
# end point: (190.7105698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (202.8705698753751, 188.2724968081464, 0.0)
#
# end point: (204.0865698753752, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (204.0865698753752, 188.2724968081464, 0.0)
#
# end point: (204.0865698753752, 187.0564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (204.0865698753752, 172.4644968081464, 0.0)
#
# end point: (204.0865698753752, 170.0324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (202.8705698753751, 171.2484968081464, 0.0)
#
# end point: (204.0865698753752, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (204.0865698753752, 174.8964968081464, 0.0)
#
# end point: (204.0865698753752, 172.4644968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (202.8705698753751, 173.6804968081464, 0.0)
#
# end point: (204.0865698753752, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 114.0964968081464, 0.0)
#
# end point: (160.3105698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 112.8804968081464, 0.0)
#
# end point: (161.5265698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 123.8244968081464, 0.0)
#
# end point: (160.3105698753751, 121.3924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (161.5265698753751, 122.6084968081464, 0.0)
#
# end point: (160.3105698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (159.0945698753751, 222.3204968081464, 0.0)
#
# end point: (161.5265698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 222.3204968081464, 0.0)
#
# end point: (160.3105698753751, 221.1044968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (160.3105698753751, 213.8084968081464, 0.0)
#
# end point: (160.3105698753751, 211.3764968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (161.5265698753751, 212.5924968081464, 0.0)
#
# end point: (160.3105698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 123.8244968081464, 0.0)
#
# end point: (177.3345698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 122.6084968081464, 0.0)
#
# end point: (178.5505698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 174.8964968081464, 0.0)
#
# end point: (177.3345698753751, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 173.6804968081464, 0.0)
#
# end point: (178.5505698753751, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (188.2785698753752, 212.5924968081464, 0.0)
#
# end point: (190.7105698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 212.5924968081464, 0.0)
#
# end point: (189.4945698753751, 211.3764968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 208.9444968081465, 0.0)
#
# end point: (189.4945698753751, 207.7284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (189.4945698753751, 207.7284968081464, 0.0)
#
# end point: (190.7105698753751, 207.7284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 133.5524968081464, 0.0)
#
# end point: (177.3345698753751, 131.1204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 132.3364968081464, 0.0)
#
# end point: (177.3345698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 189.4884968081464, 0.0)
#
# end point: (177.3345698753751, 187.0564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 188.2724968081464, 0.0)
#
# end point: (178.5505698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (178.5505698753751, 171.2484968081464, 0.0)
#
# end point: (177.3345698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 171.2484968081464, 0.0)
#
# end point: (177.3345698753751, 170.0324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (177.3345698753751, 160.3044968081464, 0.0)
#
# end point: (177.3345698753751, 157.8724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (176.1185698753751, 159.0884968081464, 0.0)
#
# end point: (177.3345698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (204.0865698753752, 109.2324968081464, 0.0)
#
# end point: (204.0865698753752, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (202.8705698753751, 108.0164968081464, 0.0)
#
# end point: (204.0865698753752, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 222.3204968081464, 0.0)
#
# end point: (50.87056987537514, 221.1044968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (106.8065698753752, 172.4644968081464, 0.0)
#
# end point: (106.8065698753752, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (106.8065698753752, 171.2484968081464, 0.0)
#
# end point: (108.0225698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (108.0225698753751, 176.1124968081464, 0.0)
#
# end point: (106.8065698753752, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (106.8065698753752, 176.1124968081464, 0.0)
#
# end point: (106.8065698753752, 174.8964968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (106.8065698753752, 174.8964968081464, 0.0)
#
# end point: (106.8065698753752, 172.4644968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (105.5905698753751, 173.6804968081464, 0.0)
#
# end point: (106.8065698753752, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (93.43056987537511, 188.2724968081464, 0.0)
#
# end point: (92.21456987537512, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (92.21456987537512, 188.2724968081464, 0.0)
#
# end point: (92.21456987537512, 187.0564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (92.21456987537512, 160.3044968081464, 0.0)
#
# end point: (90.99856987537513, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (90.99856987537513, 159.0884968081464, 0.0)
#
# end point: (93.43056987537511, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 188.2724968081464, 0.0)
#
# end point: (144.5025698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 188.2724968081464, 0.0)
#
# end point: (143.2865698753751, 189.4884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 188.2724968081464, 0.0)
#
# end point: (143.2865698753751, 187.0564968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 177.3284968081464, 0.0)
#
# end point: (143.2865698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 176.1124968081464, 0.0)
#
# end point: (143.2865698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 184.6244968081464, 0.0)
#
# end point: (143.2865698753751, 183.4084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 183.4084968081464, 0.0)
#
# end point: (143.2865698753751, 183.4084968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 183.4084968081464, 0.0)
#
# end point: (143.2865698753751, 182.1924968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 146.9284968081464, 0.0)
#
# end point: (143.2865698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 146.9284968081464, 0.0)
#
# end point: (143.2865698753751, 145.7124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 140.8484968081464, 0.0)
#
# end point: (143.2865698753751, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 139.6324968081464, 0.0)
#
# end point: (143.2865698753751, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 139.6324968081464, 0.0)
#
# end point: (143.2865698753751, 138.4164968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 133.5524968081464, 0.0)
#
# end point: (142.0705698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 132.3364968081464, 0.0)
#
# end point: (144.5025698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 171.2484968081464, 0.0)
#
# end point: (143.2865698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 171.2484968081464, 0.0)
#
# end point: (143.2865698753751, 170.0324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 165.1684968081464, 0.0)
#
# end point: (143.2865698753751, 163.9524968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 163.9524968081464, 0.0)
#
# end point: (143.2865698753751, 163.9524968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 163.9524968081464, 0.0)
#
# end point: (143.2865698753751, 162.7364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 160.3044968081464, 0.0)
#
# end point: (142.0705698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 159.0884968081464, 0.0)
#
# end point: (144.5025698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 159.0884968081464, 0.0)
#
# end point: (52.08656987537512, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 159.0884968081464, 0.0)
#
# end point: (50.87056987537514, 160.3044968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 159.0884968081464, 0.0)
#
# end point: (50.87056987537514, 157.8724968081464, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (38.62583840175279, 56.7281987674899, 0.0)
#
# end point: (53.82583840175278, 41.52819876748989, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (57.62583840175278, 40.5781987674899, 0.0)
#
# end point: (61.4258384017528, 38.6781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (57.62583840175278, 38.6781987674899, 0.0)
#
# end point: (61.4258384017528, 40.5781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (57.62583840175278, 36.7781987674899, 0.0)
#
# end point: (61.4258384017528, 34.8781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (57.62583840175278, 34.8781987674899, 0.0)
#
# end point: (61.4258384017528, 36.7781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (57.62583840175278, 32.9781987674899, 0.0)
#
# end point: (61.4258384017528, 31.0781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (57.62583840175278, 31.0781987674899, 0.0)
#
# end point: (61.4258384017528, 32.9781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (69.02583840175282, 29.1781987674899, 0.0)
#
# end point: (72.82583840175278, 27.2781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (69.02583840175282, 27.2781987674899, 0.0)
#
# end point: (72.82583840175278, 29.1781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (69.02583840175282, 25.37819876748991, 0.0)
#
# end point: (72.82583840175278, 23.4781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (69.02583840175282, 23.4781987674899, 0.0)
#
# end point: (72.82583840175278, 25.37819876748991, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (69.02583840175282, 21.5781987674899, 0.0)
#
# end point: (72.82583840175278, 19.6781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (69.02583840175282, 19.6781987674899, 0.0)
#
# end point: (72.82583840175278, 21.5781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (84.22583840175275, 56.7281987674899, 0.0)
#
# end point: (99.42583840175281, 41.52819876748989, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (103.2258384017527, 29.1781987674899, 0.0)
#
# end point: (107.0258384017528, 27.2781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (103.2258384017527, 27.2781987674899, 0.0)
#
# end point: (107.0258384017528, 29.1781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (103.2258384017527, 25.37819876748991, 0.0)
#
# end point: (107.0258384017528, 23.4781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (103.2258384017527, 23.4781987674899, 0.0)
#
# end point: (107.0258384017528, 25.37819876748991, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (103.2258384017527, 21.5781987674899, 0.0)
#
# end point: (107.0258384017528, 19.6781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (103.2258384017527, 19.6781987674899, 0.0)
#
# end point: (107.0258384017528, 21.5781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (126.0258384017528, 40.5781987674899, 0.0)
#
# end point: (129.8258384017527, 38.6781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (126.0258384017528, 38.6781987674899, 0.0)
#
# end point: (129.8258384017527, 40.5781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (126.0258384017528, 36.7781987674899, 0.0)
#
# end point: (129.8258384017527, 34.8781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (126.0258384017528, 34.8781987674899, 0.0)
#
# end point: (129.8258384017527, 36.7781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (126.0258384017528, 32.9781987674899, 0.0)
#
# end point: (129.8258384017527, 31.0781987674899, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (126.0258384017528, 31.0781987674899, 0.0)
#
# end point: (129.8258384017527, 32.9781987674899, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (142.0705698753751, 193.1364968081464, 0.0)
#
# end point: (143.2865698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (143.2865698753751, 193.1364968081464, 0.0)
#
# end point: (143.2865698753751, 191.9204968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 146.9284968081464, 0.0)
#
# end point: (52.08656987537512, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 146.9284968081464, 0.0)
#
# end point: (50.87056987537514, 148.1444968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 146.9284968081464, 0.0)
#
# end point: (50.87056987537514, 145.7124968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 140.8484968081464, 0.0)
#
# end point: (49.65456987537513, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 139.6324968081464, 0.0)
#
# end point: (52.08656987537512, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537514, 99.50449680814641, 0.0)
#
# end point: (49.65456987537513, 98.2884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 98.2884968081464, 0.0)
#
# end point: (52.08656987537512, 98.2884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 103.1524968081464, 0.0)
#
# end point: (50.87056987537514, 104.3684968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 103.1524968081464, 0.0)
#
# end point: (50.87056987537514, 101.9364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (217.4625698753752, 112.8804968081464, 0.0)
#
# end point: (218.2225698753752, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (217.4625698753752, 122.6084968081464, 0.0)
#
# end point: (218.2225698753752, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (217.4625698753752, 222.3204968081464, 0.0)
#
# end point: (218.2225698753752, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (217.4625698753752, 212.5924968081464, 0.0)
#
# end point: (218.2225698753752, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537511, 159.0884968081464, 0.0)
#
# end point: (39.92656987537512, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537511, 222.3204968081464, 0.0)
#
# end point: (39.92656987537512, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537511, 108.0164968081464, 0.0)
#
# end point: (39.92656987537512, 108.0164968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537511, 146.9284968081464, 0.0)
#
# end point: (39.92656987537512, 146.9284968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 222.3204968081464, 0.0)
#
# end point: (149.3665698753751, 222.3204968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 222.3204968081464, 0.0)
#
# end point: (148.1505698753751, 222.9284968081465, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 222.3204968081464, 0.0)
#
# end point: (210.1665698753751, 222.3204968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 222.3204968081464, 0.0)
#
# end point: (211.3825698753752, 222.9284968081465, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 188.2724968081464, 0.0)
#
# end point: (149.3665698753751, 188.2724968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 188.2724968081464, 0.0)
#
# end point: (148.1505698753751, 188.8804968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 159.0884968081464, 0.0)
#
# end point: (149.3665698753751, 159.0884968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 159.0884968081464, 0.0)
#
# end point: (148.1505698753751, 159.6964968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 132.3364968081464, 0.0)
#
# end point: (149.3665698753751, 132.3364968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 132.3364968081464, 0.0)
#
# end point: (148.1505698753751, 132.9444968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 212.5924968081464, 0.0)
#
# end point: (210.1665698753751, 212.5924968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 212.5924968081464, 0.0)
#
# end point: (211.3825698753752, 213.2004968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 122.6084968081464, 0.0)
#
# end point: (210.1665698753751, 122.6084968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 122.6084968081464, 0.0)
#
# end point: (211.3825698753752, 123.2164968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 112.8804968081464, 0.0)
#
# end point: (210.1665698753751, 112.8804968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 112.8804968081464, 0.0)
#
# end point: (211.3825698753752, 113.4884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (170.0385698753752, 222.3204968081464, 0.0)
#
# end point: (171.2545698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (167.6065698753751, 222.3204968081464, 0.0)
#
# end point: (166.3905698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 222.3204968081464, 0.0)
#
# end point: (178.5505698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (174.9025698753751, 222.3204968081464, 0.0)
#
# end point: (173.6865698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (190.7105698753751, 224.7524968081464, 0.0)
#
# end point: (191.9265698753751, 223.5364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (193.1425698753751, 222.3204968081464, 0.0)
#
# end point: (190.7105698753751, 223.5364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (189.4945698753751, 222.3204968081464, 0.0)
#
# end point: (194.3585698753751, 222.3204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (191.3185698753751, 225.3604968081464, 0.0)
#
# end point: (192.5345698753751, 224.1444968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (193.1425698753751, 222.3204968081464, 0.0)
#
# end point: (190.7105698753751, 221.1044968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (190.7105698753751, 221.1044968081464, 0.0)
#
# end point: (190.7105698753751, 223.5364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (193.1425698753751, 221.1044968081464, 0.0)
#
# end point: (193.1425698753751, 223.5364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (167.6065698753751, 212.5924968081464, 0.0)
#
# end point: (168.8225698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (171.2532928044003, 212.5945711013654, 0.0)
#
# end point: (168.5185698753751, 211.0724968081465, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (171.2532928044003, 212.5945711013654, 0.0)
#
# end point: (172.4692928044002, 212.5945711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (167.6065698753751, 217.4564968081464, 0.0)
#
# end point: (168.8225698753751, 217.4564968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (171.2532928044003, 217.4585711013654, 0.0)
#
# end point: (168.5185698753751, 215.9364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (171.2532928044003, 217.4585711013654, 0.0)
#
# end point: (172.4692928044002, 217.4585711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (192.8385698753751, 213.5044968081464, 0.0)
#
# end point: (195.5745698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (195.5732928044002, 212.5945711013654, 0.0)
#
# end point: (196.7892928044001, 212.5945711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (193.1425698753751, 212.5924968081464, 0.0)
#
# end point: (193.1425698753751, 213.8084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (191.9265698753751, 212.5924968081464, 0.0)
#
# end point: (193.1425698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (167.6065698753751, 132.3364968081464, 0.0)
#
# end point: (165.1745698753751, 133.5524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (165.1745698753751, 132.3364968081464, 0.0)
#
# end point: (167.6065698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (167.6065698753751, 132.3364968081464, 0.0)
#
# end point: (165.1745698753751, 131.1204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (165.1745698753751, 131.1204968081464, 0.0)
#
# end point: (165.1745698753751, 133.5524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (167.6065698753751, 131.1204968081464, 0.0)
#
# end point: (167.6065698753751, 133.5524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (182.1985698753751, 188.2724968081464, 0.0)
#
# end point: (183.4145698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (185.8452928044003, 188.2745711013654, 0.0)
#
# end point: (183.1105698753751, 186.7524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (185.8452928044003, 188.2745711013654, 0.0)
#
# end point: (187.0612928044003, 188.2745711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (182.1985698753751, 193.1364968081464, 0.0)
#
# end point: (183.4145698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (185.8452928044003, 193.1385711013654, 0.0)
#
# end point: (183.1105698753751, 191.6164968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (185.8452928044003, 193.1385711013654, 0.0)
#
# end point: (187.0612928044003, 193.1385711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 149.3604968081464, 0.0)
#
# end point: (178.5505698753751, 151.7924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 151.7924968081464, 0.0)
#
# end point: (177.3345698753751, 149.3604968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 149.3604968081464, 0.0)
#
# end point: (176.1185698753751, 151.7924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (176.1185698753751, 151.7924968081464, 0.0)
#
# end point: (178.5505698753751, 151.7924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (176.1185698753751, 149.3604968081464, 0.0)
#
# end point: (178.5505698753751, 149.3604968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (165.1745698753751, 122.6084968081464, 0.0)
#
# end point: (166.3905698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (168.8212928044003, 122.6105711013654, 0.0)
#
# end point: (166.0865698753752, 121.0884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (168.8212928044003, 122.6105711013654, 0.0)
#
# end point: (170.0372928044002, 122.6105711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (170.0385698753752, 112.8804968081464, 0.0)
#
# end point: (171.2545698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# ...
#
# start point: (177.3345698753751, 112.8804968081464, 0.0)
#
# end point: (178.5505698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (174.9025698753751, 112.8804968081464, 0.0)
#
# end point: (173.6865698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (188.2785698753752, 115.3124968081464, 0.0)
#
# end point: (189.4945698753751, 114.0964968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (190.7105698753751, 112.8804968081464, 0.0)
#
# end point: (188.2785698753752, 114.0964968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (187.0625698753751, 112.8804968081464, 0.0)
#
# end point: (191.9265698753751, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (188.8865698753751, 115.9204968081464, 0.0)
#
# end point: (190.1025698753751, 114.7044968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (190.7105698753751, 112.8804968081464, 0.0)
#
# end point: (188.2785698753752, 111.6644968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (188.2785698753752, 111.6644968081464, 0.0)
#
# end point: (188.2785698753752, 114.0964968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (190.7105698753751, 111.6644968081464, 0.0)
#
# end point: (190.7105698753751, 114.0964968081464, 0.0)
#
# LINE on layer: GSuperSymbol
#
# start point: (180.9825698753751, 171.2484968081464, 0.0)
#
# end point: (182.1985698753751, 171.2484968081464, 0.0)
#
# LINE on layer: GSuperSymbol
#
# start point: (184.6305698753751, 173.6804968081464, 0.0)
#
# end point: (185.8465698753752, 173.6804968081464, 0.0)
#
# LINE on layer: GSuperSymbol
#
# start point: (184.6305698753751, 171.2484968081464, 0.0)
#
# end point: (185.8465698753752, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (182.1985698753751, 174.2884968081464, 0.0)
#
# end point: (184.6305698753751, 173.0724968081464, 0.0)
#
# LINE on layer: EPLAN100
#
# start point: (182.1985698753751, 171.8564968081464, 0.0)
#
# end point: (184.6305698753751, 170.6404968081464, 0.0)
#
# LINE on layer: GSuperSymbol
#
# start point: (180.9825698753751, 173.6804968081464, 0.0)
#
# end point: (182.1985698753751, 173.6804968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 207.7284968081464, 0.0)
#
# end point: (210.1665698753751, 207.7284968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (211.3825698753752, 207.7284968081464, 0.0)
#
# end point: (211.3825698753752, 208.3364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 198.0004968081464, 0.0)
#
# end point: (176.1185698753751, 195.5684968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 195.5684968081464, 0.0)
#
# end point: (177.3345698753751, 198.0004968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (177.3345698753751, 198.0004968081464, 0.0)
#
# end point: (178.5505698753751, 195.5684968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (178.5505698753751, 195.5684968081464, 0.0)
#
# end point: (176.1185698753751, 195.5684968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (178.5505698753751, 198.0004968081464, 0.0)
#
# end point: (176.1185698753751, 198.0004968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 108.0164968081464, 0.0)
#
# end point: (149.3665698753751, 108.0164968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (148.1505698753751, 108.0164968081464, 0.0)
#
# end point: (148.1505698753751, 108.6244968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (184.6305698753751, 212.5924968081464, 0.0)
#
# end point: (185.8465698753752, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (182.1985698753751, 212.5924968081464, 0.0)
#
# end point: (180.9825698753751, 212.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (194.3585698753751, 188.2724968081464, 0.0)
#
# end point: (195.5745698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (191.9265698753751, 188.2724968081464, 0.0)
#
# end point: (190.7105698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (184.6305698753751, 122.6084968081464, 0.0)
#
# end point: (185.8465698753752, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (182.1985698753751, 122.6084968081464, 0.0)
#
# end point: (180.9825698753751, 122.6084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (217.4625698753752, 207.7284968081464, 0.0)
#
# end point: (218.2225698753752, 207.7284968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (136.5985698753751, 145.7124968081464, 0.0)
#
# end point: (131.7345698753751, 145.7124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (131.7345698753751, 148.1444968081464, 0.0)
#
# end point: (136.5985698753751, 148.1444968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 132.3364968081464, 0.0)
#
# end point: (129.9105698753751, 132.3364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 193.1364968081464, 0.0)
#
# end point: (129.9105698753751, 193.1364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 188.2724968081464, 0.0)
#
# end point: (129.9105698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 163.9524968081464, 0.0)
#
# end point: (129.9105698753751, 163.9524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (59.38129280440026, 173.6825711013654, 0.0)
#
# end point: (56.64656987537512, 172.1604968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (55.73456987537511, 173.6804968081464, 0.0)
#
# end point: (56.95056987537515, 173.6804968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (59.38129280440026, 173.6825711013654, 0.0)
#
# end point: (60.59729280440024, 173.6825711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (57.55856987537512, 175.5044968081464, 0.0)
#
# end point: (58.7745698753751, 175.5044968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (58.16656987537513, 173.2244968081464, 0.0)
#
# end point: (58.16656987537513, 173.6075368081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (58.16656987537513, 174.1364968081464, 0.0)
#
# end point: (58.16656987537513, 174.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (58.7745698753751, 175.5044968081464, 0.0)
#
# end point: (58.7745698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (57.55856987537512, 174.8964968081464, 0.0)
#
# end point: (57.55856987537512, 175.5044968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (58.16656987537513, 174.8964968081464, 0.0)
#
# end point: (58.16656987537513, 175.3524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (65.91856987537514, 159.0884968081464, 0.0)
#
# end point: (66.67856987537516, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (78.83729280440025, 159.0905711013654, 0.0)
#
# end point: (76.10256987537514, 157.5684968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (75.1905698753751, 159.0884968081464, 0.0)
#
# end point: (76.40656987537511, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (78.83729280440025, 159.0905711013654, 0.0)
#
# end point: (80.05329280440021, 159.0905711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (77.01456987537512, 160.9124968081464, 0.0)
#
# end point: (78.23056987537512, 160.9124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (77.62256987537518, 158.6324968081464, 0.0)
#
# end point: (77.62256987537518, 159.0155368081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (77.62256987537518, 159.5444968081464, 0.0)
#
# end point: (77.62256987537518, 160.0004968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (78.23056987537512, 160.9124968081464, 0.0)
#
# end point: (78.23056987537512, 161.5204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (77.01456987537512, 160.3044968081464, 0.0)
#
# end point: (77.01456987537512, 160.9124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (77.62256987537518, 160.3044968081464, 0.0)
#
# end point: (77.62256987537518, 160.7604968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (80.05456987537514, 172.4644968081464, 0.0)
#
# end point: (75.1905698753751, 172.4644968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (80.05456987537514, 174.8964968081464, 0.0)
#
# end point: (75.1905698753751, 174.8964968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (121.3985698753751, 176.1124968081464, 0.0)
#
# end point: (120.1825698753752, 176.1124968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (121.3985698753751, 176.1124968081464, 0.0)
#
# end point: (121.3985698753751, 176.7204968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (121.3985698753751, 171.2484968081464, 0.0)
#
# end point: (120.1825698753752, 171.2484968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (121.3985698753751, 171.2484968081464, 0.0)
#
# end point: (121.3985698753751, 171.8564968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (109.2385698753751, 171.2484968081464, 0.0)
#
# end point: (110.4545698753751, 171.2484968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (112.8852928044002, 171.2505711013654, 0.0)
#
# end point: (110.1505698753751, 169.7284968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (112.8852928044002, 171.2505711013654, 0.0)
#
# end point: (114.1012928044002, 171.2505711013654, 0.0)
#
# LINE on layer: 0
#
# start point: (99.5105698753751, 173.6804968081464, 0.0)
#
# end point: (100.7265698753751, 173.6804968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (99.5105698753751, 173.6804968081464, 0.0)
#
# end point: (99.5105698753751, 174.2884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 183.4084968081464, 0.0)
#
# end point: (129.9105698753751, 183.4084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (115.3172928044002, 188.2745711013654, 0.0)
#
# end point: (112.5825698753751, 186.7524968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (111.6705698753751, 188.2724968081464, 0.0)
#
# end point: (112.8865698753751, 188.2724968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (115.3172928044002, 188.2745711013654, 0.0)
#
# end point: (116.5332928044003, 188.2745711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (113.4945698753751, 190.0964968081464, 0.0)
#
# end point: (114.7105698753751, 190.0964968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.1025698753751, 187.8164968081464, 0.0)
#
# end point: (114.1025698753751, 188.1995368081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.1025698753751, 188.7284968081464, 0.0)
#
# end point: (114.1025698753751, 189.1844968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.7105698753751, 190.0964968081464, 0.0)
#
# end point: (114.7105698753751, 190.7044968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (113.4945698753751, 189.4884968081464, 0.0)
#
# end point: (113.4945698753751, 190.0964968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.1025698753751, 189.4884968081464, 0.0)
#
# end point: (114.1025698753751, 189.9444968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (115.3172928044002, 159.0905711013654, 0.0)
#
# end point: (112.5825698753751, 157.5684968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (111.6705698753751, 159.0884968081464, 0.0)
#
# end point: (112.8865698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (115.3172928044002, 159.0905711013654, 0.0)
#
# end point: (116.5332928044003, 159.0905711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (113.4945698753751, 160.9124968081464, 0.0)
#
# end point: (114.7105698753751, 160.9124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.1025698753751, 158.6324968081464, 0.0)
#
# end point: (114.1025698753751, 159.0155368081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.1025698753751, 159.5444968081464, 0.0)
#
# end point: (114.1025698753751, 160.0004968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.7105698753751, 160.9124968081464, 0.0)
#
# end point: (114.7105698753751, 161.5204968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (113.4945698753751, 160.3044968081464, 0.0)
#
# end point: (113.4945698753751, 160.9124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (114.1025698753751, 160.3044968081464, 0.0)
#
# end point: (114.1025698753751, 160.7604968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 159.0884968081464, 0.0)
#
# end point: (129.9105698753751, 159.0884968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (109.2385698753751, 176.1124968081464, 0.0)
#
# end point: (110.4545698753751, 176.1124968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (112.8852928044002, 176.1145711013654, 0.0)
#
# end point: (110.1505698753751, 174.5924968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (112.8852928044002, 176.1145711013654, 0.0)
#
# end point: (114.1012928044002, 176.1145711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (129.150569875375, 139.6324968081464, 0.0)
#
# end point: (129.9105698753751, 139.6324968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (121.3985698753751, 146.9284968081464, 0.0)
#
# end point: (120.1825698753752, 146.9284968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (121.3985698753751, 146.9284968081464, 0.0)
#
# end point: (121.3985698753751, 147.5364968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (99.5105698753751, 146.9284968081464, 0.0)
#
# end point: (100.7265698753751, 146.9284968081464, 0.0)
#
# LINE on layer: 0
#
# start point: (99.5105698753751, 146.9284968081464, 0.0)
#
# end point: (99.5105698753751, 147.5364968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (108.0225698753751, 146.9284968081464, 0.0)
#
# end point: (109.2385698753751, 146.9284968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (111.6692928044002, 146.9305711013654, 0.0)
#
# end point: (108.9345698753751, 145.4084968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (111.6692928044002, 146.9305711013654, 0.0)
#
# end point: (112.8852928044002, 146.9305711013654, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537511, 139.6324968081464, 0.0)
#
# end point: (39.92656987537512, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537511, 98.2884968081464, 0.0)
#
# end point: (39.92656987537512, 98.2884968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (37.49456987537513, 112.8804968081464, 0.0)
#
# end point: (38.25456987537513, 112.8804968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (37.49456987537513, 227.1844968081464, 0.0)
#
# end point: (38.25456987537513, 227.1844968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (54.51856987537514, 139.6324968081464, 0.0)
#
# end point: (55.27856987537512, 139.6324968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537517, 103.1524968081463, 0.0)
#
# end point: (39.92656987537515, 103.1524968081463, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (50.87056987537517, 103.1524968081463, 0.0)
#
# end point: (218.5189647813857, 103.1524968081463, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537516, 103.1524968081463, 0.0)
#
# end point: (52.08656987537515, 103.1524968081463, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (39.16656987537513, 103.1524968081463, 0.0)
#
# end point: (39.92656987537515, 103.1524968081463, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (59.21933530216317, 103.1524968081463, 0.0)
#
# end point: (59.97933530216318, 103.1524968081463, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (219.4309647813856, 103.1524968081463, 0.0)
#
# end point: (220.1909647813857, 103.1524968081463, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.2065698753751, 216.8484968081464, 0.0)
#
# end point: (214.4225698753751, 218.0644968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (213.2065698753751, 218.0644968081464, 0.0)
#
# end point: (214.4225698753751, 216.8484968081464, 0.0)
#
# LINE on layer: EPLAN533
#
# start point: (50.87056987537514, 223.5364968081464, 0.0)
#
# end point: (50.87056987537516, 232.3475256943905, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 222.3204968081464, 0.0)
#
# end point: (50.87056987537514, 223.5364968081464, 0.0)
#
# LINE on layer: EPLAN311
#
# start point: (49.65456987537513, 222.3204968081464, 0.0)
#
# end point: (50.87056987537514, 221.1044968081464, 0.0)
#
# LINE on layer: EPLAN300
#
# start point: (219.0477347360073, 232.3475256943905, 0.0)
#
# end point: (219.8077347360073, 232.3475256943905, 0.0)
#
# LINE on layer: 0
#
# start point: (218.5917347360073, 232.3475256943905, 0.0)
#
# end point: (50.87056987537514, 232.3475256943905, 0.0)

# %% [markdown]
# 所有布局对象都支持标准的Python迭代器协议和in操作符。

# %% [markdown]
# ### 访问实体的DXF属性
#
# `e.dxftype()`方法返回DXF类型，DXF类型始终是大写字符串，例如“LINE”。实体的所有DXF属性都分组在dxf名称空间属性中：

# %%
e.dxf.layer  # 实体所在的层，作为字符串
# Out:
# '0'

# %%
e.dxf.color  # 实体的颜色编号，作为整数
# Out:
# 256

# %% [markdown]
# 如果未设置DXF属性（DXF属性不存在），则将引发DXFValueError。在这种情况下，get()方法返回默认值或者如果没有指定默认值，则返回None：

# %%
p = e.dxf.get("paperspace", 0)  # 如果DXF属性'paperspace'不存在，则实体默认为模型空间。
p
# Out:
# 0

# %% [markdown]
# 或者可以事先检查属性是否存在：

# %%
e.dxf.hasattr("paperspace")
# Out:
# False

# %% [markdown]
# 不支持的DXF属性会引发DXFAttributeError，要检查实体是否支持某个属性，请使用：

# %%
e.dxf.is_supported("paperspace")
# Out:
# True

# %% [markdown]
# ### 获取纸张空间布局

# %%
psp = doc.paperspace("布局1")

# %% [markdown]
# 上述代码检索名为layout0的纸张空间，Paperspace对象的用法与模型空间对象相同。 DXF R12仅提供一个纸张空间，因此在方法调用`doc.paperspace("layout0")`中忽略纸张空间名称或可以省略。对于新的DXF版本，您可以使用`layout_names()`和`layout_names_in_taborder()`方法获取可用布局名称列表。

# %% [markdown]
# ### 通过查询语言检索实体
#
# Ezdxf为DXF实体提供了灵活的查询语言。所有布局类型都具有query()方法以启动实体查询或使用ezdxf.query.new()函数。
#
# 查询字符串是两个查询的组合，首先是所需的实体查询，然后是可选的属性查询，用方括号括起来：“EntityQuery[AttributeQuery]”
#
# 实体查询是DXF实体名称的空格分隔列表或特殊名称*。其中*表示所有DXF实体，所有DXF名称都必须大写。 搜索可以通过添加具有感叹号前缀的实体名称（例如！LINE）来排除实体类型。
#
# 属性查询用于按其DXF属性选择DXF实体。属性查询是实体查询的补充，仅在实体已匹配实体查询时才会匹配。属性查询是一个布尔表达式，支持运算符：and、or、!。
#
# 获取模型空间中的所有LINE实体：

# %%
msp = doc.modelspace()
lines = msp.query("LINE")

# %% [markdown]
# 容器EntityQuery还提供了query()方法，以进一步细化查询，例如检索所有构造层上的所有LINE实体：

# %%
construction_lines = lines.query('*[layer=="construction"]')

# %% [markdown]
# \*是所有DXF类型的通配符，在这种情况下，您也可以使用LINE而不是\*，在此处起作用，因为源仅包含LINE实体。
#
# 这可以作为单个查询执行：

# %%
lines = msp.query('LINE[layer=="construction"]')
lines

# %% [markdown]
# 检索除了具有虚线类型以外的所有构造层模型空间实体的高级查询：

# %%
not_dashed_entities = msp.query('*[layer=="construction" & linetype!="DASHED"]')

# %% [markdown]
# ### EntityQuery的扩展功能
#
# EntityQuery类具有属性和重载运算符，可通过Python特性而不是查询字符串来构建扩展查询。
#
# 与上一节中相同的任务，但使用EntityQuery容器的功能：

# %%
# 重载的rational operator返回EntityQuery对象而不是bool值！
lines = msp.query("LINES").layer == "construction"
not_dashed_lines = lines.linetype != "DASHED"

# %% [markdown]
# ### 按groupby()函数检索实体
#
# groupby()函数按用户定义的标准搜索和分组实体。例如，让我们按图层对模型空间中的所有实体进行分组，结果将是一个字典，其中图层名称为dict-key，与匹配此图层的所有实体列表相关联的字典值。

# %%
from ezdxf.groupby import groupby
group = groupby(entities=msp, dxfattrib="layer")
group
# Out:
# {'GPDRAW': [<class 'ezdxf.entities.insert.Insert'> INSERT(#5C4),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#612)],
#  'EPLAN311': [<class 'ezdxf.entities.line.Line'> LINE(#8AF),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B0),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B2),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B3),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B4),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B5),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B7),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B8),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B9),
#   <class 'ezdxf.entities.line.Line'> LINE(#8BA),
#   <class 'ezdxf.entities.line.Line'> LINE(#8BF),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C2),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C3),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C4),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C5),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C6),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C7),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C8),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C9),
#   <class 'ezdxf.entities.line.Line'> LINE(#8CA),
#   <class 'ezdxf.entities.line.Line'> LINE(#8CB),
#   <class 'ezdxf.entities.line.Line'> LINE(#8CC),
#   <class 'ezdxf.entities.line.Line'> LINE(#8CD),
#   <class 'ezdxf.entities.line.Line'> LINE(#8CE),
#   <class 'ezdxf.entities.line.Line'> LINE(#8CF),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D0),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D1),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D2),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D3),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D4),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D5),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D6),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D7),
#   <class 'ezdxf.entities.line.Line'> LINE(#8D8),
#   <class 'ezdxf.entities.line.Line'> LINE(#8DD),
#   <class 'ezdxf.entities.line.Line'> LINE(#8DF),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E0),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E1),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E2),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E3),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E5),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E6),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E7),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E8),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E9),
#   <class 'ezdxf.entities.line.Line'> LINE(#8EA),
#   <class 'ezdxf.entities.line.Line'> LINE(#8EB),
#   <class 'ezdxf.entities.line.Line'> LINE(#8EC),
#   <class 'ezdxf.entities.line.Line'> LINE(#8ED),
#   <class 'ezdxf.entities.line.Line'> LINE(#8EE),
#   <class 'ezdxf.entities.line.Line'> LINE(#8EF),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F0),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F3),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F4),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F5),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F8),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F9),
#   <class 'ezdxf.entities.line.Line'> LINE(#8FF),
#   <class 'ezdxf.entities.line.Line'> LINE(#900),
#   <class 'ezdxf.entities.line.Line'> LINE(#901),
#   <class 'ezdxf.entities.line.Line'> LINE(#902),
#   <class 'ezdxf.entities.line.Line'> LINE(#904),
#   <class 'ezdxf.entities.line.Line'> LINE(#907),
#   <class 'ezdxf.entities.line.Line'> LINE(#908),
#   <class 'ezdxf.entities.line.Line'> LINE(#909),
#   <class 'ezdxf.entities.line.Line'> LINE(#90A),
#   <class 'ezdxf.entities.line.Line'> LINE(#90B),
#   <class 'ezdxf.entities.line.Line'> LINE(#90F),
#   <class 'ezdxf.entities.line.Line'> LINE(#910),
#   <class 'ezdxf.entities.line.Line'> LINE(#911),
#   <class 'ezdxf.entities.line.Line'> LINE(#915),
#   <class 'ezdxf.entities.line.Line'> LINE(#916),
#   <class 'ezdxf.entities.line.Line'> LINE(#917),
#   <class 'ezdxf.entities.line.Line'> LINE(#91B),
#   <class 'ezdxf.entities.line.Line'> LINE(#91D),
#   <class 'ezdxf.entities.line.Line'> LINE(#91E),
#   <class 'ezdxf.entities.line.Line'> LINE(#92A),
#   <class 'ezdxf.entities.line.Line'> LINE(#92C),
#   <class 'ezdxf.entities.line.Line'> LINE(#92D),
#   <class 'ezdxf.entities.line.Line'> LINE(#92E),
#   <class 'ezdxf.entities.line.Line'> LINE(#92F),
#   <class 'ezdxf.entities.line.Line'> LINE(#930),
#   <class 'ezdxf.entities.line.Line'> LINE(#931),
#   <class 'ezdxf.entities.line.Line'> LINE(#932),
#   <class 'ezdxf.entities.line.Line'> LINE(#933),
#   <class 'ezdxf.entities.line.Line'> LINE(#934),
#   <class 'ezdxf.entities.line.Line'> LINE(#935),
#   <class 'ezdxf.entities.line.Line'> LINE(#936),
#   <class 'ezdxf.entities.line.Line'> LINE(#937),
#   <class 'ezdxf.entities.line.Line'> LINE(#938),
#   <class 'ezdxf.entities.line.Line'> LINE(#93A),
#   <class 'ezdxf.entities.line.Line'> LINE(#93B),
#   <class 'ezdxf.entities.line.Line'> LINE(#93C),
#   <class 'ezdxf.entities.line.Line'> LINE(#93E),
#   <class 'ezdxf.entities.line.Line'> LINE(#93F),
#   <class 'ezdxf.entities.line.Line'> LINE(#940),
#   <class 'ezdxf.entities.line.Line'> LINE(#941),
#   <class 'ezdxf.entities.line.Line'> LINE(#942),
#   <class 'ezdxf.entities.line.Line'> LINE(#944),
#   <class 'ezdxf.entities.line.Line'> LINE(#945),
#   <class 'ezdxf.entities.line.Line'> LINE(#946),
#   <class 'ezdxf.entities.line.Line'> LINE(#947),
#   <class 'ezdxf.entities.line.Line'> LINE(#948),
#   <class 'ezdxf.entities.line.Line'> LINE(#949),
#   <class 'ezdxf.entities.line.Line'> LINE(#94A),
#   <class 'ezdxf.entities.line.Line'> LINE(#94B),
#   <class 'ezdxf.entities.line.Line'> LINE(#94C),
#   <class 'ezdxf.entities.line.Line'> LINE(#94D),
#   <class 'ezdxf.entities.line.Line'> LINE(#952),
#   <class 'ezdxf.entities.line.Line'> LINE(#953),
#   <class 'ezdxf.entities.line.Line'> LINE(#954),
#   <class 'ezdxf.entities.line.Line'> LINE(#961),
#   <class 'ezdxf.entities.line.Line'> LINE(#962),
#   <class 'ezdxf.entities.line.Line'> LINE(#963),
#   <class 'ezdxf.entities.line.Line'> LINE(#964),
#   <class 'ezdxf.entities.line.Line'> LINE(#965),
#   <class 'ezdxf.entities.line.Line'> LINE(#966),
#   <class 'ezdxf.entities.line.Line'> LINE(#967),
#   <class 'ezdxf.entities.line.Line'> LINE(#968),
#   <class 'ezdxf.entities.line.Line'> LINE(#96E),
#   <class 'ezdxf.entities.line.Line'> LINE(#96F),
#   <class 'ezdxf.entities.line.Line'> LINE(#970),
#   <class 'ezdxf.entities.line.Line'> LINE(#971),
#   <class 'ezdxf.entities.line.Line'> LINE(#972),
#   <class 'ezdxf.entities.line.Line'> LINE(#973),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#974),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#975),
#   <class 'ezdxf.entities.line.Line'> LINE(#976),
#   <class 'ezdxf.entities.line.Line'> LINE(#977),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#978),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#979),
#   <class 'ezdxf.entities.line.Line'> LINE(#97A),
#   <class 'ezdxf.entities.line.Line'> LINE(#97B),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#97C),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#97D),
#   <class 'ezdxf.entities.line.Line'> LINE(#97E),
#   <class 'ezdxf.entities.line.Line'> LINE(#97F),
#   <class 'ezdxf.entities.line.Line'> LINE(#980),
#   <class 'ezdxf.entities.line.Line'> LINE(#981),
#   <class 'ezdxf.entities.line.Line'> LINE(#982),
#   <class 'ezdxf.entities.line.Line'> LINE(#983),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#984),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#985),
#   <class 'ezdxf.entities.line.Line'> LINE(#986),
#   <class 'ezdxf.entities.line.Line'> LINE(#987),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#988),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#989),
#   <class 'ezdxf.entities.line.Line'> LINE(#98A),
#   <class 'ezdxf.entities.line.Line'> LINE(#98B),
#   <class 'ezdxf.entities.line.Line'> LINE(#98C),
#   <class 'ezdxf.entities.line.Line'> LINE(#98D),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#98E),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#98F),
#   <class 'ezdxf.entities.line.Line'> LINE(#990),
#   <class 'ezdxf.entities.line.Line'> LINE(#991),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#992),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#993),
#   <class 'ezdxf.entities.line.Line'> LINE(#994),
#   <class 'ezdxf.entities.line.Line'> LINE(#995),
#   <class 'ezdxf.entities.line.Line'> LINE(#996),
#   <class 'ezdxf.entities.line.Line'> LINE(#997),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#998),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#999),
#   <class 'ezdxf.entities.line.Line'> LINE(#99A),
#   <class 'ezdxf.entities.line.Line'> LINE(#99B),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#99C),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#99D),
#   <class 'ezdxf.entities.line.Line'> LINE(#99E),
#   <class 'ezdxf.entities.line.Line'> LINE(#99F),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9A0),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9A1),
#   <class 'ezdxf.entities.line.Line'> LINE(#9A2),
#   <class 'ezdxf.entities.line.Line'> LINE(#9A3),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9A4),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9A5),
#   <class 'ezdxf.entities.line.Line'> LINE(#9A6),
#   <class 'ezdxf.entities.line.Line'> LINE(#9A7),
#   <class 'ezdxf.entities.line.Line'> LINE(#9A8),
#   <class 'ezdxf.entities.line.Line'> LINE(#9A9),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9AA),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9AB),
#   <class 'ezdxf.entities.line.Line'> LINE(#9AC),
#   <class 'ezdxf.entities.line.Line'> LINE(#9AD),
#   <class 'ezdxf.entities.line.Line'> LINE(#9AE),
#   <class 'ezdxf.entities.line.Line'> LINE(#9AF),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9B0),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9B1),
#   <class 'ezdxf.entities.line.Line'> LINE(#9B2),
#   <class 'ezdxf.entities.line.Line'> LINE(#9B3),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9B4),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9B5),
#   <class 'ezdxf.entities.line.Line'> LINE(#9B6),
#   <class 'ezdxf.entities.line.Line'> LINE(#9B7),
#   <class 'ezdxf.entities.line.Line'> LINE(#9B8),
#   <class 'ezdxf.entities.line.Line'> LINE(#9B9),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9BA),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9BB),
#   <class 'ezdxf.entities.line.Line'> LINE(#9BC),
#   <class 'ezdxf.entities.line.Line'> LINE(#9BD),
#   <class 'ezdxf.entities.line.Line'> LINE(#9BF),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C0),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C1),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C2),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C3),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C4),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C5),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#9C6),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#9C7),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C8),
#   <class 'ezdxf.entities.line.Line'> LINE(#9C9),
#   <class 'ezdxf.entities.line.Line'> LINE(#9CA),
#   <class 'ezdxf.entities.line.Line'> LINE(#9CB),
#   <class 'ezdxf.entities.line.Line'> LINE(#9CC),
#   <class 'ezdxf.entities.line.Line'> LINE(#9CD),
#   <class 'ezdxf.entities.line.Line'> LINE(#9CE),
#   <class 'ezdxf.entities.line.Line'> LINE(#9CF),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D0),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D1),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D2),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D3),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D4),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D5),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D6),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D7),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D8),
#   <class 'ezdxf.entities.line.Line'> LINE(#9D9),
#   <class 'ezdxf.entities.line.Line'> LINE(#9DA),
#   <class 'ezdxf.entities.line.Line'> LINE(#9DB),
#   <class 'ezdxf.entities.line.Line'> LINE(#9DC),
#   <class 'ezdxf.entities.line.Line'> LINE(#9DD),
#   <class 'ezdxf.entities.line.Line'> LINE(#9DE),
#   <class 'ezdxf.entities.line.Line'> LINE(#9DF),
#   <class 'ezdxf.entities.line.Line'> LINE(#9E0),
#   <class 'ezdxf.entities.line.Line'> LINE(#9E1),
#   <class 'ezdxf.entities.line.Line'> LINE(#9E2),
#   <class 'ezdxf.entities.line.Line'> LINE(#9E3),
#   <class 'ezdxf.entities.line.Line'> LINE(#9E4),
#   <class 'ezdxf.entities.line.Line'> LINE(#A62),
#   <class 'ezdxf.entities.line.Line'> LINE(#A63),
#   <class 'ezdxf.entities.line.Line'> LINE(#A64),
#   <class 'ezdxf.entities.line.Line'> LINE(#A65),
#   <class 'ezdxf.entities.line.Line'> LINE(#A66),
#   <class 'ezdxf.entities.line.Line'> LINE(#A67),
#   <class 'ezdxf.entities.line.Line'> LINE(#A68),
#   <class 'ezdxf.entities.line.Line'> LINE(#A6F),
#   <class 'ezdxf.entities.line.Line'> LINE(#A70),
#   <class 'ezdxf.entities.line.Line'> LINE(#A72),
#   <class 'ezdxf.entities.line.Line'> LINE(#A73),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#BFD),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#BFE),
#   <class 'ezdxf.entities.line.Line'> LINE(#BFF),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#C02),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#C03),
#   <class 'ezdxf.entities.line.Line'> LINE(#C04),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#C07),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#C08),
#   <class 'ezdxf.entities.line.Line'> LINE(#C09),
#   <class 'ezdxf.entities.line.Line'> LINE(#1078),
#   <class 'ezdxf.entities.line.Line'> LINE(#1079),
#   <class 'ezdxf.entities.line.Line'> LINE(#107E),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#1085),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#1086),
#   <class 'ezdxf.entities.line.Line'> LINE(#108D),
#   <class 'ezdxf.entities.line.Line'> LINE(#108E),
#   <class 'ezdxf.entities.line.Line'> LINE(#10A9),
#   <class 'ezdxf.entities.line.Line'> LINE(#10AA)],
#  'EPLAN533': [<class 'ezdxf.entities.line.Line'> LINE(#8B1),
#   <class 'ezdxf.entities.line.Line'> LINE(#8B6),
#   <class 'ezdxf.entities.line.Line'> LINE(#8BB),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C0),
#   <class 'ezdxf.entities.line.Line'> LINE(#8C1),
#   <class 'ezdxf.entities.line.Line'> LINE(#903),
#   <class 'ezdxf.entities.line.Line'> LINE(#905),
#   <class 'ezdxf.entities.line.Line'> LINE(#906),
#   <class 'ezdxf.entities.line.Line'> LINE(#90C),
#   <class 'ezdxf.entities.line.Line'> LINE(#90D),
#   <class 'ezdxf.entities.line.Line'> LINE(#90E),
#   <class 'ezdxf.entities.line.Line'> LINE(#912),
#   <class 'ezdxf.entities.line.Line'> LINE(#913),
#   <class 'ezdxf.entities.line.Line'> LINE(#914),
#   <class 'ezdxf.entities.line.Line'> LINE(#918),
#   <class 'ezdxf.entities.line.Line'> LINE(#919),
#   <class 'ezdxf.entities.line.Line'> LINE(#91A),
#   <class 'ezdxf.entities.line.Line'> LINE(#91C),
#   <class 'ezdxf.entities.line.Line'> LINE(#922),
#   <class 'ezdxf.entities.line.Line'> LINE(#923),
#   <class 'ezdxf.entities.line.Line'> LINE(#10A7)],
#  'EPLAN510': [<class 'ezdxf.entities.line.Line'> LINE(#8D9),
#   <class 'ezdxf.entities.line.Line'> LINE(#8DA),
#   <class 'ezdxf.entities.line.Line'> LINE(#8DB),
#   <class 'ezdxf.entities.line.Line'> LINE(#8DC),
#   <class 'ezdxf.entities.line.Line'> LINE(#8DE),
#   <class 'ezdxf.entities.line.Line'> LINE(#8E4),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F1),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F2),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F6),
#   <class 'ezdxf.entities.line.Line'> LINE(#8F7),
#   <class 'ezdxf.entities.line.Line'> LINE(#8FA),
#   <class 'ezdxf.entities.line.Line'> LINE(#8FB),
#   <class 'ezdxf.entities.line.Line'> LINE(#8FC),
#   <class 'ezdxf.entities.line.Line'> LINE(#8FD),
#   <class 'ezdxf.entities.line.Line'> LINE(#8FE),
#   <class 'ezdxf.entities.line.Line'> LINE(#92B),
#   <class 'ezdxf.entities.line.Line'> LINE(#943)],
#  'EPLAN542': [<class 'ezdxf.entities.line.Line'> LINE(#939),
#   <class 'ezdxf.entities.line.Line'> LINE(#93D)],
#  'EPLAN110': [<class 'ezdxf.entities.text.Text'> TEXT(#955),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#956),
#   <class 'ezdxf.entities.text.Text'> TEXT(#957),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#958),
#   <class 'ezdxf.entities.text.Text'> TEXT(#959),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#95A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#95B),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#95C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#95D),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#95E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#95F),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#960),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9E5),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9E6),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9E7),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9E8),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9E9),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9EA),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9EB),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9EC),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9ED),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9EE),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A74),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A75)],
#  'EPLAN100': [<class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9EF),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9F0),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9F1),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9F2),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9F3),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9F4),
#   <class 'ezdxf.entities.line.Line'> LINE(#9F5),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9F9),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9FA),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9FB),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9FC),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9FD),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9FE),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#9FF),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A00),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A01),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A02),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A03),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A04),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A05),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A06),
#   <class 'ezdxf.entities.line.Line'> LINE(#A07),
#   <class 'ezdxf.entities.line.Line'> LINE(#A08),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A09),
#   <class 'ezdxf.entities.line.Line'> LINE(#A0A),
#   <class 'ezdxf.entities.line.Line'> LINE(#A0B),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A0C),
#   <class 'ezdxf.entities.line.Line'> LINE(#A0D),
#   <class 'ezdxf.entities.line.Line'> LINE(#A0E),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A0F),
#   <class 'ezdxf.entities.line.Line'> LINE(#A10),
#   <class 'ezdxf.entities.line.Line'> LINE(#A11),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A12),
#   <class 'ezdxf.entities.line.Line'> LINE(#A13),
#   <class 'ezdxf.entities.line.Line'> LINE(#A14),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A15),
#   <class 'ezdxf.entities.line.Line'> LINE(#A16),
#   <class 'ezdxf.entities.line.Line'> LINE(#A17),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A23),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A24),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A25),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A26),
#   <class 'ezdxf.entities.line.Line'> LINE(#A27),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A2B),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A2C),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A2D),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A2E),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A2F),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A30),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A31),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A32),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A33),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A34),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A35),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A36),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A37),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A38),
#   <class 'ezdxf.entities.line.Line'> LINE(#A39),
#   <class 'ezdxf.entities.line.Line'> LINE(#A3A),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A3B),
#   <class 'ezdxf.entities.line.Line'> LINE(#A3C),
#   <class 'ezdxf.entities.line.Line'> LINE(#A3D),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A3E),
#   <class 'ezdxf.entities.line.Line'> LINE(#A3F),
#   <class 'ezdxf.entities.line.Line'> LINE(#A40),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A41),
#   <class 'ezdxf.entities.line.Line'> LINE(#A42),
#   <class 'ezdxf.entities.line.Line'> LINE(#A43),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A44),
#   <class 'ezdxf.entities.line.Line'> LINE(#A45),
#   <class 'ezdxf.entities.line.Line'> LINE(#A46),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A47),
#   <class 'ezdxf.entities.line.Line'> LINE(#A48),
#   <class 'ezdxf.entities.line.Line'> LINE(#A49),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A52),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A53),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A54),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A55),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A56),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A58),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A59),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A5A),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#ADA),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B03),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B0F),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B11),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B21),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B33),
#   <class 'ezdxf.entities.line.Line'> LINE(#B34),
#   <class 'ezdxf.entities.line.Line'> LINE(#B35)],
#  'EPLAN108': [<class 'ezdxf.entities.text.Text'> TEXT(#9F6),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9F7),
#   <class 'ezdxf.entities.text.Text'> TEXT(#9F8),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A18),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A19),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A1A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A1B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A1C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A1D),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A1E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A1F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A20),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A21),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A22),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A28),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A29),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A2A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A4A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A4B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A4C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A4D),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A4E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A4F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A50),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A51),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A57),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A5B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A5C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A5D),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A5F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A60),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A61),
#   <class 'ezdxf.entities.mtext.MText'> MTEXT(#C0A),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#C0B)],
#  '0': [<class 'ezdxf.entities.text.Text'> TEXT(#A5E),
#   <class 'ezdxf.entities.line.Line'> LINE(#AAD),
#   <class 'ezdxf.entities.line.Line'> LINE(#AAE),
#   <class 'ezdxf.entities.line.Line'> LINE(#AB2),
#   <class 'ezdxf.entities.line.Line'> LINE(#AB3),
#   <class 'ezdxf.entities.line.Line'> LINE(#AB6),
#   <class 'ezdxf.entities.line.Line'> LINE(#AB7),
#   <class 'ezdxf.entities.line.Line'> LINE(#ABA),
#   <class 'ezdxf.entities.line.Line'> LINE(#ABB),
#   <class 'ezdxf.entities.line.Line'> LINE(#ABE),
#   <class 'ezdxf.entities.line.Line'> LINE(#ABF),
#   <class 'ezdxf.entities.line.Line'> LINE(#AC3),
#   <class 'ezdxf.entities.line.Line'> LINE(#AC4),
#   <class 'ezdxf.entities.line.Line'> LINE(#AC8),
#   <class 'ezdxf.entities.line.Line'> LINE(#AC9),
#   <class 'ezdxf.entities.line.Line'> LINE(#ACD),
#   <class 'ezdxf.entities.line.Line'> LINE(#ACE),
#   <class 'ezdxf.entities.line.Line'> LINE(#B3A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B3B),
#   <class 'ezdxf.entities.line.Line'> LINE(#B48),
#   <class 'ezdxf.entities.line.Line'> LINE(#B49),
#   <class 'ezdxf.entities.line.Line'> LINE(#B9F),
#   <class 'ezdxf.entities.line.Line'> LINE(#BA0),
#   <class 'ezdxf.entities.line.Line'> LINE(#BA3),
#   <class 'ezdxf.entities.line.Line'> LINE(#BA4),
#   <class 'ezdxf.entities.line.Line'> LINE(#BAB),
#   <class 'ezdxf.entities.line.Line'> LINE(#BAC),
#   <class 'ezdxf.entities.line.Line'> LINE(#BEB),
#   <class 'ezdxf.entities.line.Line'> LINE(#BEC),
#   <class 'ezdxf.entities.line.Line'> LINE(#BEF),
#   <class 'ezdxf.entities.line.Line'> LINE(#BF0),
#   <class 'ezdxf.entities.line.Line'> LINE(#10B0),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#1309),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#1324),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#133F),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#135A),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#1375),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#1392),
#   <class 'ezdxf.entities.insert.Insert'> INSERT(#13E9)],
#  'EPLAN400': [<class 'ezdxf.entities.text.Text'> TEXT(#A79),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A7C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A7F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A82),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A85),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A88),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A8B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A91),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A95),
#   <class 'ezdxf.entities.text.Text'> TEXT(#A99),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AA3),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ACF),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AD0),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AD4),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AD5),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AD9),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ADB),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AE7),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AEB),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AEF),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AF4),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AFA),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AFE),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B02),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B08),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B0E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B10),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B12),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B16),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B17),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B1B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B1C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B20),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B22),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B2E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B2F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B40),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B4A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B4B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B4F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B50),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B54),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B55),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B59),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B65),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B68),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B6B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B6E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B71),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B7F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B82),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B99),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BA5),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BAD),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BB0),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BBE),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BCC),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BCF),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BD3),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BE5),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BF1),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BF5),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BF8),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BFB),
#   <class 'ezdxf.entities.text.Text'> TEXT(#C00),
#   <class 'ezdxf.entities.text.Text'> TEXT(#C05),
#   <class 'ezdxf.entities.text.Text'> TEXT(#107A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#1087),
#   <class 'ezdxf.entities.text.Text'> TEXT(#10AB)],
#  'EPLAN300': [<class 'ezdxf.entities.line.Line'> LINE(#A7A),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A7B),
#   <class 'ezdxf.entities.line.Line'> LINE(#A7D),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A7E),
#   <class 'ezdxf.entities.line.Line'> LINE(#A80),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A81),
#   <class 'ezdxf.entities.line.Line'> LINE(#A83),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A84),
#   <class 'ezdxf.entities.line.Line'> LINE(#A86),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A87),
#   <class 'ezdxf.entities.line.Line'> LINE(#A89),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A8A),
#   <class 'ezdxf.entities.line.Line'> LINE(#A8C),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A8D),
#   <class 'ezdxf.entities.line.Line'> LINE(#A96),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#A97),
#   <class 'ezdxf.entities.line.Line'> LINE(#AD1),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#AD2),
#   <class 'ezdxf.entities.line.Line'> LINE(#AD3),
#   <class 'ezdxf.entities.line.Line'> LINE(#AD6),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#AD7),
#   <class 'ezdxf.entities.line.Line'> LINE(#AD8),
#   <class 'ezdxf.entities.line.Line'> LINE(#ADC),
#   <class 'ezdxf.entities.line.Line'> LINE(#ADD),
#   <class 'ezdxf.entities.line.Line'> LINE(#ADE),
#   <class 'ezdxf.entities.line.Line'> LINE(#ADF),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#AE0),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#AE1),
#   <class 'ezdxf.entities.line.Line'> LINE(#AE2),
#   <class 'ezdxf.entities.line.Line'> LINE(#AE3),
#   <class 'ezdxf.entities.line.Line'> LINE(#AE4),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#AE5),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#AE6),
#   <class 'ezdxf.entities.line.Line'> LINE(#AE8),
#   <class 'ezdxf.entities.line.Line'> LINE(#AE9),
#   <class 'ezdxf.entities.line.Line'> LINE(#AEA),
#   <class 'ezdxf.entities.line.Line'> LINE(#AEC),
#   <class 'ezdxf.entities.line.Line'> LINE(#AED),
#   <class 'ezdxf.entities.line.Line'> LINE(#AEE),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF0),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF1),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF2),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF3),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF5),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF6),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF7),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF8),
#   <class 'ezdxf.entities.line.Line'> LINE(#AF9),
#   <class 'ezdxf.entities.line.Line'> LINE(#AFB),
#   <class 'ezdxf.entities.line.Line'> LINE(#AFC),
#   <class 'ezdxf.entities.line.Line'> LINE(#AFD),
#   <class 'ezdxf.entities.line.Line'> LINE(#AFF),
#   <class 'ezdxf.entities.line.Line'> LINE(#B00),
#   <class 'ezdxf.entities.line.Line'> LINE(#B01),
#   <class 'ezdxf.entities.line.Line'> LINE(#B09),
#   <class 'ezdxf.entities.line.Line'> LINE(#B0A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B0B),
#   <class 'ezdxf.entities.line.Line'> LINE(#B0C),
#   <class 'ezdxf.entities.line.Line'> LINE(#B0D),
#   <class 'ezdxf.entities.line.Line'> LINE(#B13),
#   <class 'ezdxf.entities.line.Line'> LINE(#B14),
#   <class 'ezdxf.entities.line.Line'> LINE(#B15),
#   <class 'ezdxf.entities.line.Line'> LINE(#B18),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B19),
#   <class 'ezdxf.entities.line.Line'> LINE(#B1A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B1D),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B1E),
#   <class 'ezdxf.entities.line.Line'> LINE(#B1F),
#   <class 'ezdxf.entities.line.Line'> LINE(#B23),
#   <class 'ezdxf.entities.line.Line'> LINE(#B24),
#   <class 'ezdxf.entities.line.Line'> LINE(#B25),
#   <class 'ezdxf.entities.line.Line'> LINE(#B26),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B27),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#B28),
#   <class 'ezdxf.entities.line.Line'> LINE(#B29),
#   <class 'ezdxf.entities.line.Line'> LINE(#B2A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B2B),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B2C),
#   <class 'ezdxf.entities.hatch.Hatch'> HATCH(#B2D),
#   <class 'ezdxf.entities.line.Line'> LINE(#B41),
#   <class 'ezdxf.entities.line.Line'> LINE(#B42),
#   <class 'ezdxf.entities.line.Line'> LINE(#B43),
#   <class 'ezdxf.entities.line.Line'> LINE(#B44),
#   <class 'ezdxf.entities.line.Line'> LINE(#B45),
#   <class 'ezdxf.entities.line.Line'> LINE(#B4C),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B4D),
#   <class 'ezdxf.entities.line.Line'> LINE(#B4E),
#   <class 'ezdxf.entities.line.Line'> LINE(#B51),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B52),
#   <class 'ezdxf.entities.line.Line'> LINE(#B53),
#   <class 'ezdxf.entities.line.Line'> LINE(#B56),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B57),
#   <class 'ezdxf.entities.line.Line'> LINE(#B58),
#   <class 'ezdxf.entities.line.Line'> LINE(#B5A),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B5B),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B61),
#   <class 'ezdxf.entities.line.Line'> LINE(#B62),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B63),
#   <class 'ezdxf.entities.line.Line'> LINE(#B64),
#   <class 'ezdxf.entities.line.Line'> LINE(#B66),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B67),
#   <class 'ezdxf.entities.line.Line'> LINE(#B69),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B6A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B6C),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B6D),
#   <class 'ezdxf.entities.line.Line'> LINE(#B6F),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B70),
#   <class 'ezdxf.entities.line.Line'> LINE(#B76),
#   <class 'ezdxf.entities.line.Line'> LINE(#B77),
#   <class 'ezdxf.entities.line.Line'> LINE(#B78),
#   <class 'ezdxf.entities.line.Line'> LINE(#B79),
#   <class 'ezdxf.entities.line.Line'> LINE(#B7A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B7B),
#   <class 'ezdxf.entities.line.Line'> LINE(#B7C),
#   <class 'ezdxf.entities.line.Line'> LINE(#B7D),
#   <class 'ezdxf.entities.line.Line'> LINE(#B7E),
#   <class 'ezdxf.entities.line.Line'> LINE(#B80),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B81),
#   <class 'ezdxf.entities.line.Line'> LINE(#B87),
#   <class 'ezdxf.entities.line.Line'> LINE(#B88),
#   <class 'ezdxf.entities.line.Line'> LINE(#B89),
#   <class 'ezdxf.entities.line.Line'> LINE(#B8A),
#   <class 'ezdxf.entities.line.Line'> LINE(#B8B),
#   <class 'ezdxf.entities.line.Line'> LINE(#B8C),
#   <class 'ezdxf.entities.line.Line'> LINE(#B8D),
#   <class 'ezdxf.entities.line.Line'> LINE(#B8E),
#   <class 'ezdxf.entities.line.Line'> LINE(#B8F),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B95),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#B96),
#   <class 'ezdxf.entities.line.Line'> LINE(#B97),
#   <class 'ezdxf.entities.line.Line'> LINE(#B98),
#   <class 'ezdxf.entities.line.Line'> LINE(#BA6),
#   <class 'ezdxf.entities.line.Line'> LINE(#BA7),
#   <class 'ezdxf.entities.line.Line'> LINE(#BA8),
#   <class 'ezdxf.entities.line.Line'> LINE(#BAE),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BAF),
#   <class 'ezdxf.entities.line.Line'> LINE(#BB5),
#   <class 'ezdxf.entities.line.Line'> LINE(#BB6),
#   <class 'ezdxf.entities.line.Line'> LINE(#BB7),
#   <class 'ezdxf.entities.line.Line'> LINE(#BB8),
#   <class 'ezdxf.entities.line.Line'> LINE(#BB9),
#   <class 'ezdxf.entities.line.Line'> LINE(#BBA),
#   <class 'ezdxf.entities.line.Line'> LINE(#BBB),
#   <class 'ezdxf.entities.line.Line'> LINE(#BBC),
#   <class 'ezdxf.entities.line.Line'> LINE(#BBD),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC3),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC4),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC5),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC6),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC7),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC8),
#   <class 'ezdxf.entities.line.Line'> LINE(#BC9),
#   <class 'ezdxf.entities.line.Line'> LINE(#BCA),
#   <class 'ezdxf.entities.line.Line'> LINE(#BCB),
#   <class 'ezdxf.entities.line.Line'> LINE(#BCD),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BCE),
#   <class 'ezdxf.entities.line.Line'> LINE(#BD0),
#   <class 'ezdxf.entities.line.Line'> LINE(#BD1),
#   <class 'ezdxf.entities.line.Line'> LINE(#BD2),
#   <class 'ezdxf.entities.line.Line'> LINE(#BD4),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BD5),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BE2),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BE3),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#BE4),
#   <class 'ezdxf.entities.line.Line'> LINE(#BF2),
#   <class 'ezdxf.entities.line.Line'> LINE(#BF3),
#   <class 'ezdxf.entities.line.Line'> LINE(#BF4),
#   <class 'ezdxf.entities.line.Line'> LINE(#BF6),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BF7),
#   <class 'ezdxf.entities.line.Line'> LINE(#BF9),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#BFA),
#   <class 'ezdxf.entities.line.Line'> LINE(#1081),
#   <class 'ezdxf.entities.line.Line'> LINE(#1088),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#1089),
#   <class 'ezdxf.entities.line.Line'> LINE(#108C),
#   <class 'ezdxf.entities.line.Line'> LINE(#10AC),
#   <class 'ezdxf.entities.circle.Circle'> CIRCLE(#10AD)],
#  'EPLAN501': [<class 'ezdxf.entities.text.Text'> TEXT(#A92),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B9A),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BDA),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BE6)],
#  'EPLAN492': [<class 'ezdxf.entities.text.Text'> TEXT(#A93),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B9B),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BE7)],
#  'EPLAN305': [<class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#A94),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#B9C),
#   <class 'ezdxf.entities.lwpolyline.LWPolyline'> LWPOLYLINE(#BE8)],
#  'EPLAN420': [<class 'ezdxf.entities.text.Text'> TEXT(#AAB),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AAF),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AB4),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AB8),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ABC),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AC0),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AC5),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ACA),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B04),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B06),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B37),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B3C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B3E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B46),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B5D),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B5F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B72),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B74),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B83),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B85),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B91),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B93),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B9D),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BA1),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BA9),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BB1),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BB3),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BBF),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BC1),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BD6),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BD8),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BE9),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BED),
#   <class 'ezdxf.entities.text.Text'> TEXT(#108F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#11B0)],
#  'EPLAN512': [<class 'ezdxf.entities.text.Text'> TEXT(#AAC),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AB1),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AB5),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AB9),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ABD),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AC2),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AC7),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ACC),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B39),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B47),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B9E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BA2),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BAA),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BEA),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BEE)],
#  'EPLAN421': [<class 'ezdxf.entities.text.Text'> TEXT(#AB0),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AC1),
#   <class 'ezdxf.entities.text.Text'> TEXT(#AC6),
#   <class 'ezdxf.entities.text.Text'> TEXT(#ACB),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B05),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B07),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B38),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B3D),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B3F),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B5E),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B60),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B73),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B75),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B84),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B86),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B92),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B94),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BB2),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BB4),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BC0),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BC2),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BD7),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BD9)],
#  'GSuperSymbol': [<class 'ezdxf.entities.line.Line'> LINE(#B30),
#   <class 'ezdxf.entities.line.Line'> LINE(#B31),
#   <class 'ezdxf.entities.line.Line'> LINE(#B32),
#   <class 'ezdxf.entities.line.Line'> LINE(#B36)],
#  'EPLAN408': [<class 'ezdxf.entities.text.Text'> TEXT(#B5C),
#   <class 'ezdxf.entities.text.Text'> TEXT(#B90),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BDB),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BE0),
#   <class 'ezdxf.entities.text.Text'> TEXT(#BE1)],
#  'EPLAN500': [<class 'ezdxf.entities.text.Text'> TEXT(#BDC)],
#  'EPLAN504': [<class 'ezdxf.entities.text.Text'> TEXT(#BDD)],
#  'EPLAN502': [<class 'ezdxf.entities.text.Text'> TEXT(#BDE)],
#  'EPLAN503': [<class 'ezdxf.entities.text.Text'> TEXT(#BDF)]}

# %% [markdown]
# entities参数可以是任何容器或生成器，该生成器产生DXF实体：

# %%
group = msp.groupby(dxfattrib="layer")#按照layer属性分组

for layer, entities in group.items():#遍历字典
    print(f'Layer "{layer}" contains following entities:')
    for entity in entities:
        print(f"    {entity}")
    print("-"*40)
# Out:
# Layer "GPDRAW" contains following entities:
#     INSERT(#5C4)
#     INSERT(#612)
# ----------------------------------------
# Layer "EPLAN311" contains following entities:
#     LINE(#8AF)
#     LINE(#8B0)
#     LINE(#8B2)
#     LINE(#8B3)
#     LINE(#8B4)
#     LINE(#8B5)
#     LINE(#8B7)
#     LINE(#8B8)
#     LINE(#8B9)
#     LINE(#8BA)
#     LINE(#8BF)
#     LINE(#8C2)
#     LINE(#8C3)
#     LINE(#8C4)
#     LINE(#8C5)
#     LINE(#8C6)
#     LINE(#8C7)
#     LINE(#8C8)
#     LINE(#8C9)
#     LINE(#8CA)
#     LINE(#8CB)
#     LINE(#8CC)
#     LINE(#8CD)
#     LINE(#8CE)
#     LINE(#8CF)
#     LINE(#8D0)
#     LINE(#8D1)
#     LINE(#8D2)
#     LINE(#8D3)
#     LINE(#8D4)
#     LINE(#8D5)
#     LINE(#8D6)
#     LINE(#8D7)
#     LINE(#8D8)
#     LINE(#8DD)
#     LINE(#8DF)
#     LINE(#8E0)
#     LINE(#8E1)
#     LINE(#8E2)
#     LINE(#8E3)
#     LINE(#8E5)
#     LINE(#8E6)
#     LINE(#8E7)
#     LINE(#8E8)
#     LINE(#8E9)
#     LINE(#8EA)
#     LINE(#8EB)
#     LINE(#8EC)
#     LINE(#8ED)
#     LINE(#8EE)
#     LINE(#8EF)
#     LINE(#8F0)
#     LINE(#8F3)
#     LINE(#8F4)
#     LINE(#8F5)
#     LINE(#8F8)
#     LINE(#8F9)
#     LINE(#8FF)
#     LINE(#900)
#     LINE(#901)
#     LINE(#902)
#     LINE(#904)
#     LINE(#907)
#     LINE(#908)
#     LINE(#909)
#     LINE(#90A)
#     LINE(#90B)
#     LINE(#90F)
#     LINE(#910)
#     LINE(#911)
#     LINE(#915)
#     LINE(#916)
#     LINE(#917)
#     LINE(#91B)
#     LINE(#91D)
#     LINE(#91E)
#     LINE(#92A)
#     LINE(#92C)
#     LINE(#92D)
#     LINE(#92E)
#     LINE(#92F)
#     LINE(#930)
#     LINE(#931)
#     LINE(#932)
#     LINE(#933)
#     LINE(#934)
#     LINE(#935)
#     LINE(#936)
#     LINE(#937)
#     LINE(#938)
#     LINE(#93A)
#     LINE(#93B)
#     LINE(#93C)
#     LINE(#93E)
#     LINE(#93F)
#     LINE(#940)
#     LINE(#941)
#     LINE(#942)
#     LINE(#944)
#     LINE(#945)
#     LINE(#946)
#     LINE(#947)
#     LINE(#948)
#     LINE(#949)
#     LINE(#94A)
#     LINE(#94B)
#     LINE(#94C)
#     LINE(#94D)
#     LINE(#952)
#     LINE(#953)
#     LINE(#954)
#     LINE(#961)
#     LINE(#962)
#     LINE(#963)
#     LINE(#964)
#     LINE(#965)
#     LINE(#966)
#     LINE(#967)
#     LINE(#968)
#     LINE(#96E)
#     LINE(#96F)
#     LINE(#970)
#     LINE(#971)
#     LINE(#972)
#     LINE(#973)
#     CIRCLE(#974)
#     HATCH(#975)
#     LINE(#976)
#     LINE(#977)
#     CIRCLE(#978)
#     HATCH(#979)
#     LINE(#97A)
#     LINE(#97B)
#     CIRCLE(#97C)
#     HATCH(#97D)
#     LINE(#97E)
#     LINE(#97F)
#     LINE(#980)
#     LINE(#981)
#     LINE(#982)
#     LINE(#983)
#     CIRCLE(#984)
#     HATCH(#985)
#     LINE(#986)
#     LINE(#987)
#     CIRCLE(#988)
#     HATCH(#989)
#     LINE(#98A)
#     LINE(#98B)
#     LINE(#98C)
#     LINE(#98D)
#     CIRCLE(#98E)
#     HATCH(#98F)
#     LINE(#990)
#     LINE(#991)
#     CIRCLE(#992)
#     HATCH(#993)
#     LINE(#994)
#     LINE(#995)
#     LINE(#996)
#     LINE(#997)
#     CIRCLE(#998)
#     HATCH(#999)
#     LINE(#99A)
#     LINE(#99B)
#     CIRCLE(#99C)
#     HATCH(#99D)
#     LINE(#99E)
#     LINE(#99F)
#     CIRCLE(#9A0)
#     HATCH(#9A1)
#     LINE(#9A2)
#     LINE(#9A3)
#     CIRCLE(#9A4)
#     HATCH(#9A5)
#     LINE(#9A6)
#     LINE(#9A7)
#     LINE(#9A8)
#     LINE(#9A9)
#     CIRCLE(#9AA)
#     HATCH(#9AB)
#     LINE(#9AC)
#     LINE(#9AD)
#     LINE(#9AE)
#     LINE(#9AF)
#     CIRCLE(#9B0)
#     HATCH(#9B1)
#     LINE(#9B2)
#     LINE(#9B3)
#     CIRCLE(#9B4)
#     HATCH(#9B5)
#     LINE(#9B6)
#     LINE(#9B7)
#     LINE(#9B8)
#     LINE(#9B9)
#     CIRCLE(#9BA)
#     HATCH(#9BB)
#     LINE(#9BC)
#     LINE(#9BD)
#     LINE(#9BF)
#     LINE(#9C0)
#     LINE(#9C1)
#     LINE(#9C2)
#     LINE(#9C3)
#     LINE(#9C4)
#     LINE(#9C5)
#     CIRCLE(#9C6)
#     HATCH(#9C7)
#     LINE(#9C8)
#     LINE(#9C9)
#     LINE(#9CA)
#     LINE(#9CB)
#     LINE(#9CC)
#     LINE(#9CD)
#     LINE(#9CE)
#     LINE(#9CF)
#     LINE(#9D0)
#     LINE(#9D1)
#     LINE(#9D2)
#     LINE(#9D3)
#     LINE(#9D4)
#     LINE(#9D5)
#     LINE(#9D6)
#     LINE(#9D7)
#     LINE(#9D8)
#     LINE(#9D9)
#     LINE(#9DA)
#     LINE(#9DB)
#     LINE(#9DC)
#     LINE(#9DD)
#     LINE(#9DE)
#     LINE(#9DF)
#     LINE(#9E0)
#     LINE(#9E1)
#     LINE(#9E2)
#     LINE(#9E3)
#     LINE(#9E4)
#     LINE(#A62)
#     LINE(#A63)
#     LINE(#A64)
#     LINE(#A65)
#     LINE(#A66)
#     LINE(#A67)
#     LINE(#A68)
#     LINE(#A6F)
#     LINE(#A70)
#     LINE(#A72)
#     LINE(#A73)
#     LWPOLYLINE(#BFD)
#     HATCH(#BFE)
#     LINE(#BFF)
#     LWPOLYLINE(#C02)
#     HATCH(#C03)
#     LINE(#C04)
#     LWPOLYLINE(#C07)
#     HATCH(#C08)
#     LINE(#C09)
#     LINE(#1078)
#     LINE(#1079)
#     LINE(#107E)
#     LWPOLYLINE(#1085)
#     HATCH(#1086)
#     LINE(#108D)
#     LINE(#108E)
#     LINE(#10A9)
#     LINE(#10AA)
# ----------------------------------------
# Layer "EPLAN533" contains following entities:
#     LINE(#8B1)
#     LINE(#8B6)
#     LINE(#8BB)
#     LINE(#8C0)
#     LINE(#8C1)
#     LINE(#903)
#     LINE(#905)
#     LINE(#906)
#     LINE(#90C)
#     LINE(#90D)
#     LINE(#90E)
#     LINE(#912)
#     LINE(#913)
#     LINE(#914)
#     LINE(#918)
#     LINE(#919)
#     LINE(#91A)
#     LINE(#91C)
#     LINE(#922)
#     LINE(#923)
#     LINE(#10A7)
# ----------------------------------------
# Layer "EPLAN510" contains following entities:
#     LINE(#8D9)
#     LINE(#8DA)
#     LINE(#8DB)
#     LINE(#8DC)
#     LINE(#8DE)
#     LINE(#8E4)
#     LINE(#8F1)
#     LINE(#8F2)
#     LINE(#8F6)
#     LINE(#8F7)
#     LINE(#8FA)
#     LINE(#8FB)
#     LINE(#8FC)
#     LINE(#8FD)
#     LINE(#8FE)
#     LINE(#92B)
#     LINE(#943)
# ----------------------------------------
# Layer "EPLAN542" contains following entities:
#     LINE(#939)
#     LINE(#93D)
# ----------------------------------------
# Layer "EPLAN110" contains following entities:
#     TEXT(#955)
#     LWPOLYLINE(#956)
#     TEXT(#957)
#     LWPOLYLINE(#958)
#     TEXT(#959)
#     LWPOLYLINE(#95A)
#     TEXT(#95B)
#     LWPOLYLINE(#95C)
#     TEXT(#95D)
#     LWPOLYLINE(#95E)
#     TEXT(#95F)
#     LWPOLYLINE(#960)
#     TEXT(#9E5)
#     LWPOLYLINE(#9E6)
#     TEXT(#9E7)
#     LWPOLYLINE(#9E8)
#     TEXT(#9E9)
#     LWPOLYLINE(#9EA)
#     TEXT(#9EB)
#     LWPOLYLINE(#9EC)
#     TEXT(#9ED)
#     LWPOLYLINE(#9EE)
#     TEXT(#A74)
#     LWPOLYLINE(#A75)
# ----------------------------------------
# Layer "EPLAN100" contains following entities:
#     LWPOLYLINE(#9EF)
#     LWPOLYLINE(#9F0)
#     LWPOLYLINE(#9F1)
#     LWPOLYLINE(#9F2)
#     LWPOLYLINE(#9F3)
#     LWPOLYLINE(#9F4)
#     LINE(#9F5)
#     LWPOLYLINE(#9F9)
#     LWPOLYLINE(#9FA)
#     LWPOLYLINE(#9FB)
#     LWPOLYLINE(#9FC)
#     LWPOLYLINE(#9FD)
#     LWPOLYLINE(#9FE)
#     LWPOLYLINE(#9FF)
#     LWPOLYLINE(#A00)
#     LWPOLYLINE(#A01)
#     LWPOLYLINE(#A02)
#     LWPOLYLINE(#A03)
#     LWPOLYLINE(#A04)
#     LWPOLYLINE(#A05)
#     LWPOLYLINE(#A06)
#     LINE(#A07)
#     LINE(#A08)
#     LWPOLYLINE(#A09)
#     LINE(#A0A)
#     LINE(#A0B)
#     LWPOLYLINE(#A0C)
#     LINE(#A0D)
#     LINE(#A0E)
#     LWPOLYLINE(#A0F)
#     LINE(#A10)
#     LINE(#A11)
#     LWPOLYLINE(#A12)
#     LINE(#A13)
#     LINE(#A14)
#     LWPOLYLINE(#A15)
#     LINE(#A16)
#     LINE(#A17)
#     LWPOLYLINE(#A23)
#     LWPOLYLINE(#A24)
#     LWPOLYLINE(#A25)
#     LWPOLYLINE(#A26)
#     LINE(#A27)
#     LWPOLYLINE(#A2B)
#     LWPOLYLINE(#A2C)
#     LWPOLYLINE(#A2D)
#     LWPOLYLINE(#A2E)
#     LWPOLYLINE(#A2F)
#     LWPOLYLINE(#A30)
#     LWPOLYLINE(#A31)
#     LWPOLYLINE(#A32)
#     LWPOLYLINE(#A33)
#     LWPOLYLINE(#A34)
#     LWPOLYLINE(#A35)
#     LWPOLYLINE(#A36)
#     LWPOLYLINE(#A37)
#     LWPOLYLINE(#A38)
#     LINE(#A39)
#     LINE(#A3A)
#     LWPOLYLINE(#A3B)
#     LINE(#A3C)
#     LINE(#A3D)
#     LWPOLYLINE(#A3E)
#     LINE(#A3F)
#     LINE(#A40)
#     LWPOLYLINE(#A41)
#     LINE(#A42)
#     LINE(#A43)
#     LWPOLYLINE(#A44)
#     LINE(#A45)
#     LINE(#A46)
#     LWPOLYLINE(#A47)
#     LINE(#A48)
#     LINE(#A49)
#     LWPOLYLINE(#A52)
#     LWPOLYLINE(#A53)
#     LWPOLYLINE(#A54)
#     LWPOLYLINE(#A55)
#     LWPOLYLINE(#A56)
#     LWPOLYLINE(#A58)
#     LWPOLYLINE(#A59)
#     LWPOLYLINE(#A5A)
#     LWPOLYLINE(#ADA)
#     LWPOLYLINE(#B03)
#     LWPOLYLINE(#B0F)
#     LWPOLYLINE(#B11)
#     LWPOLYLINE(#B21)
#     LWPOLYLINE(#B33)
#     LINE(#B34)
#     LINE(#B35)
# ----------------------------------------
# Layer "EPLAN108" contains following entities:
#     TEXT(#9F6)
#     TEXT(#9F7)
#     TEXT(#9F8)
#     TEXT(#A18)
#     TEXT(#A19)
#     TEXT(#A1A)
#     TEXT(#A1B)
#     TEXT(#A1C)
#     TEXT(#A1D)
#     TEXT(#A1E)
#     TEXT(#A1F)
#     TEXT(#A20)
#     TEXT(#A21)
#     TEXT(#A22)
#     TEXT(#A28)
#     TEXT(#A29)
#     TEXT(#A2A)
#     TEXT(#A4A)
#     TEXT(#A4B)
#     TEXT(#A4C)
#     TEXT(#A4D)
#     TEXT(#A4E)
#     TEXT(#A4F)
#     TEXT(#A50)
#     TEXT(#A51)
#     TEXT(#A57)
#     TEXT(#A5B)
#     TEXT(#A5C)
#     TEXT(#A5D)
#     TEXT(#A5F)
#     TEXT(#A60)
#     TEXT(#A61)
#     MTEXT(#C0A)
#     LWPOLYLINE(#C0B)
# ----------------------------------------
# Layer "0" contains following entities:
#     TEXT(#A5E)
#     LINE(#AAD)
#     LINE(#AAE)
#     LINE(#AB2)
#     LINE(#AB3)
#     LINE(#AB6)
#     LINE(#AB7)
#     LINE(#ABA)
#     LINE(#ABB)
#     LINE(#ABE)
#     LINE(#ABF)
#     LINE(#AC3)
#     LINE(#AC4)
#     LINE(#AC8)
#     LINE(#AC9)
#     LINE(#ACD)
#     LINE(#ACE)
#     LINE(#B3A)
#     LINE(#B3B)
#     LINE(#B48)
#     LINE(#B49)
#     LINE(#B9F)
#     LINE(#BA0)
#     LINE(#BA3)
#     LINE(#BA4)
#     LINE(#BAB)
#     LINE(#BAC)
#     LINE(#BEB)
#     LINE(#BEC)
#     LINE(#BEF)
#     LINE(#BF0)
#     LINE(#10B0)
#     INSERT(#1309)
#     INSERT(#1324)
#     INSERT(#133F)
#     INSERT(#135A)
#     INSERT(#1375)
#     INSERT(#1392)
#     INSERT(#13E9)
# ----------------------------------------
# Layer "EPLAN400" contains following entities:
#     TEXT(#A79)
#     TEXT(#A7C)
#     TEXT(#A7F)
#     TEXT(#A82)
#     TEXT(#A85)
#     TEXT(#A88)
#     TEXT(#A8B)
#     TEXT(#A91)
#     TEXT(#A95)
#     TEXT(#A99)
#     TEXT(#AA3)
#     TEXT(#ACF)
#     TEXT(#AD0)
#     TEXT(#AD4)
#     TEXT(#AD5)
#     TEXT(#AD9)
#     TEXT(#ADB)
#     TEXT(#AE7)
#     TEXT(#AEB)
#     TEXT(#AEF)
#     TEXT(#AF4)
#     TEXT(#AFA)
#     TEXT(#AFE)
#     TEXT(#B02)
#     TEXT(#B08)
#     TEXT(#B0E)
#     TEXT(#B10)
#     TEXT(#B12)
#     TEXT(#B16)
#     TEXT(#B17)
#     TEXT(#B1B)
#     TEXT(#B1C)
#     TEXT(#B20)
#     TEXT(#B22)
#     TEXT(#B2E)
#     TEXT(#B2F)
#     TEXT(#B40)
#     TEXT(#B4A)
#     TEXT(#B4B)
#     TEXT(#B4F)
#     TEXT(#B50)
#     TEXT(#B54)
#     TEXT(#B55)
#     TEXT(#B59)
#     TEXT(#B65)
#     TEXT(#B68)
#     TEXT(#B6B)
#     TEXT(#B6E)
#     TEXT(#B71)
#     TEXT(#B7F)
#     TEXT(#B82)
#     TEXT(#B99)
#     TEXT(#BA5)
#     TEXT(#BAD)
#     TEXT(#BB0)
#     TEXT(#BBE)
#     TEXT(#BCC)
#     TEXT(#BCF)
#     TEXT(#BD3)
#     TEXT(#BE5)
#     TEXT(#BF1)
#     TEXT(#BF5)
#     TEXT(#BF8)
#     TEXT(#BFB)
#     TEXT(#C00)
#     TEXT(#C05)
#     TEXT(#107A)
#     TEXT(#1087)
#     TEXT(#10AB)
# ----------------------------------------
# Layer "EPLAN300" contains following entities:
#     LINE(#A7A)
#     CIRCLE(#A7B)
#     LINE(#A7D)
#     CIRCLE(#A7E)
#     LINE(#A80)
#     CIRCLE(#A81)
#     LINE(#A83)
#     CIRCLE(#A84)
#     LINE(#A86)
#     CIRCLE(#A87)
#     LINE(#A89)
#     CIRCLE(#A8A)
#     LINE(#A8C)
#     CIRCLE(#A8D)
#     LINE(#A96)
#     CIRCLE(#A97)
#     LINE(#AD1)
#     LWPOLYLINE(#AD2)
#     LINE(#AD3)
#     LINE(#AD6)
#     LWPOLYLINE(#AD7)
#     LINE(#AD8)
#     LINE(#ADC)
#     LINE(#ADD)
#     LINE(#ADE)
#     LINE(#ADF)
#     LWPOLYLINE(#AE0)
#     HATCH(#AE1)
#     LINE(#AE2)
#     LINE(#AE3)
#     LINE(#AE4)
#     LWPOLYLINE(#AE5)
#     HATCH(#AE6)
#     LINE(#AE8)
#     LINE(#AE9)
#     LINE(#AEA)
#     LINE(#AEC)
#     LINE(#AED)
#     LINE(#AEE)
#     LINE(#AF0)
#     LINE(#AF1)
#     LINE(#AF2)
#     LINE(#AF3)
#     LINE(#AF5)
#     LINE(#AF6)
#     LINE(#AF7)
#     LINE(#AF8)
#     LINE(#AF9)
#     LINE(#AFB)
#     LINE(#AFC)
#     LINE(#AFD)
#     LINE(#AFF)
#     LINE(#B00)
#     LINE(#B01)
#     LINE(#B09)
#     LINE(#B0A)
#     LINE(#B0B)
#     LINE(#B0C)
#     LINE(#B0D)
#     LINE(#B13)
#     LINE(#B14)
#     LINE(#B15)
#     LINE(#B18)
#     LWPOLYLINE(#B19)
#     LINE(#B1A)
#     LINE(#B1D)
#     LWPOLYLINE(#B1E)
#     LINE(#B1F)
#     LINE(#B23)
#     LINE(#B24)
#     LINE(#B25)
#     LINE(#B26)
#     LWPOLYLINE(#B27)
#     HATCH(#B28)
#     LINE(#B29)
#     LINE(#B2A)
#     LINE(#B2B)
#     LWPOLYLINE(#B2C)
#     HATCH(#B2D)
#     LINE(#B41)
#     LINE(#B42)
#     LINE(#B43)
#     LINE(#B44)
#     LINE(#B45)
#     LINE(#B4C)
#     LWPOLYLINE(#B4D)
#     LINE(#B4E)
#     LINE(#B51)
#     LWPOLYLINE(#B52)
#     LINE(#B53)
#     LINE(#B56)
#     LWPOLYLINE(#B57)
#     LINE(#B58)
#     LINE(#B5A)
#     CIRCLE(#B5B)
#     CIRCLE(#B61)
#     LINE(#B62)
#     CIRCLE(#B63)
#     LINE(#B64)
#     LINE(#B66)
#     CIRCLE(#B67)
#     LINE(#B69)
#     CIRCLE(#B6A)
#     LINE(#B6C)
#     CIRCLE(#B6D)
#     LINE(#B6F)
#     CIRCLE(#B70)
#     LINE(#B76)
#     LINE(#B77)
#     LINE(#B78)
#     LINE(#B79)
#     LINE(#B7A)
#     LINE(#B7B)
#     LINE(#B7C)
#     LINE(#B7D)
#     LINE(#B7E)
#     LINE(#B80)
#     CIRCLE(#B81)
#     LINE(#B87)
#     LINE(#B88)
#     LINE(#B89)
#     LINE(#B8A)
#     LINE(#B8B)
#     LINE(#B8C)
#     LINE(#B8D)
#     LINE(#B8E)
#     LINE(#B8F)
#     CIRCLE(#B95)
#     CIRCLE(#B96)
#     LINE(#B97)
#     LINE(#B98)
#     LINE(#BA6)
#     LINE(#BA7)
#     LINE(#BA8)
#     LINE(#BAE)
#     CIRCLE(#BAF)
#     LINE(#BB5)
#     LINE(#BB6)
#     LINE(#BB7)
#     LINE(#BB8)
#     LINE(#BB9)
#     LINE(#BBA)
#     LINE(#BBB)
#     LINE(#BBC)
#     LINE(#BBD)
#     LINE(#BC3)
#     LINE(#BC4)
#     LINE(#BC5)
#     LINE(#BC6)
#     LINE(#BC7)
#     LINE(#BC8)
#     LINE(#BC9)
#     LINE(#BCA)
#     LINE(#BCB)
#     LINE(#BCD)
#     CIRCLE(#BCE)
#     LINE(#BD0)
#     LINE(#BD1)
#     LINE(#BD2)
#     LINE(#BD4)
#     CIRCLE(#BD5)
#     CIRCLE(#BE2)
#     CIRCLE(#BE3)
#     LWPOLYLINE(#BE4)
#     LINE(#BF2)
#     LINE(#BF3)
#     LINE(#BF4)
#     LINE(#BF6)
#     CIRCLE(#BF7)
#     LINE(#BF9)
#     CIRCLE(#BFA)
#     LINE(#1081)
#     LINE(#1088)
#     CIRCLE(#1089)
#     LINE(#108C)
#     LINE(#10AC)
#     CIRCLE(#10AD)
# ----------------------------------------
# Layer "EPLAN501" contains following entities:
#     TEXT(#A92)
#     TEXT(#B9A)
#     TEXT(#BDA)
#     TEXT(#BE6)
# ----------------------------------------
# Layer "EPLAN492" contains following entities:
#     TEXT(#A93)
#     TEXT(#B9B)
#     TEXT(#BE7)
# ----------------------------------------
# Layer "EPLAN305" contains following entities:
#     LWPOLYLINE(#A94)
#     LWPOLYLINE(#B9C)
#     LWPOLYLINE(#BE8)
# ----------------------------------------
# Layer "EPLAN420" contains following entities:
#     TEXT(#AAB)
#     TEXT(#AAF)
#     TEXT(#AB4)
#     TEXT(#AB8)
#     TEXT(#ABC)
#     TEXT(#AC0)
#     TEXT(#AC5)
#     TEXT(#ACA)
#     TEXT(#B04)
#     TEXT(#B06)
#     TEXT(#B37)
#     TEXT(#B3C)
#     TEXT(#B3E)
#     TEXT(#B46)
#     TEXT(#B5D)
#     TEXT(#B5F)
#     TEXT(#B72)
#     TEXT(#B74)
#     TEXT(#B83)
#     TEXT(#B85)
#     TEXT(#B91)
#     TEXT(#B93)
#     TEXT(#B9D)
#     TEXT(#BA1)
#     TEXT(#BA9)
#     TEXT(#BB1)
#     TEXT(#BB3)
#     TEXT(#BBF)
#     TEXT(#BC1)
#     TEXT(#BD6)
#     TEXT(#BD8)
#     TEXT(#BE9)
#     TEXT(#BED)
#     TEXT(#108F)
#     TEXT(#11B0)
# ----------------------------------------
# Layer "EPLAN512" contains following entities:
#     TEXT(#AAC)
#     TEXT(#AB1)
#     TEXT(#AB5)
#     TEXT(#AB9)
#     TEXT(#ABD)
#     TEXT(#AC2)
#     TEXT(#AC7)
#     TEXT(#ACC)
#     TEXT(#B39)
#     TEXT(#B47)
#     TEXT(#B9E)
#     TEXT(#BA2)
#     TEXT(#BAA)
#     TEXT(#BEA)
#     TEXT(#BEE)
# ----------------------------------------
# Layer "EPLAN421" contains following entities:
#     TEXT(#AB0)
#     TEXT(#AC1)
#     TEXT(#AC6)
#     TEXT(#ACB)
#     TEXT(#B05)
#     TEXT(#B07)
#     TEXT(#B38)
#     TEXT(#B3D)
#     TEXT(#B3F)
#     TEXT(#B5E)
#     TEXT(#B60)
#     TEXT(#B73)
#     TEXT(#B75)
#     TEXT(#B84)
#     TEXT(#B86)
#     TEXT(#B92)
#     TEXT(#B94)
#     TEXT(#BB2)
#     TEXT(#BB4)
#     TEXT(#BC0)
#     TEXT(#BC2)
#     TEXT(#BD7)
#     TEXT(#BD9)
# ----------------------------------------
# Layer "GSuperSymbol" contains following entities:
#     LINE(#B30)
#     LINE(#B31)
#     LINE(#B32)
#     LINE(#B36)
# ----------------------------------------
# Layer "EPLAN408" contains following entities:
#     TEXT(#B5C)
#     TEXT(#B90)
#     TEXT(#BDB)
#     TEXT(#BE0)
#     TEXT(#BE1)
# ----------------------------------------
# Layer "EPLAN500" contains following entities:
#     TEXT(#BDC)
# ----------------------------------------
# Layer "EPLAN504" contains following entities:
#     TEXT(#BDD)
# ----------------------------------------
# Layer "EPLAN502" contains following entities:
#     TEXT(#BDE)
# ----------------------------------------
# Layer "EPLAN503" contains following entities:
#     TEXT(#BDF)
# ----------------------------------------

# %% [markdown]
# 上一个示例展示了如何通过单个DXF属性对实体进行分组。要进行更高级的查询，请创建自定义键函数，该函数接受DXF实体作为参数并返回哈希值作为dict-key或返回None以排除实体。
#
# 以下示例显示如何按层和颜色对实体进行分组，字典键是(layer, color)元组，并且与具有匹配DXF属性的实体所匹配的列表相关联的dict-value：

# %%
def layer_and_color_key(entity):
    # 返回None以排除来自默认层“0”的实体
    if entity.dxf.layer == "0":
        return None
    return entity.dxf.layer, entity.dxf.color
group = groupby(entities=msp, key=layer_and_color_key)

for (layer, color), entities in group.items():
    print(f'Entities on layer "{layer}" with color {color}:')
for entity in entities:
    print(f" {entity}")
print("-"*40)
# Out:
# Entities on layer "GPDRAW" with color 256:
# Entities on layer "EPLAN311" with color 256:
# Entities on layer "EPLAN533" with color 1:
# Entities on layer "EPLAN533" with color 256:
# Entities on layer "EPLAN510" with color 256:
# Entities on layer "EPLAN542" with color 256:
# Entities on layer "EPLAN311" with color 1:
# Entities on layer "EPLAN311" with color 7:
# Entities on layer "EPLAN110" with color 7:
# Entities on layer "EPLAN100" with color 256:
# Entities on layer "EPLAN100" with color 7:
# Entities on layer "EPLAN108" with color 7:
# Entities on layer "EPLAN108" with color 256:
# Entities on layer "EPLAN400" with color 256:
# Entities on layer "EPLAN300" with color 256:
# Entities on layer "EPLAN501" with color 256:
# Entities on layer "EPLAN492" with color 256:
# Entities on layer "EPLAN305" with color 256:
# Entities on layer "EPLAN420" with color 256:
# Entities on layer "EPLAN512" with color 256:
# Entities on layer "EPLAN421" with color 256:
# Entities on layer "GSuperSymbol" with color 7:
# Entities on layer "EPLAN408" with color 256:
# Entities on layer "EPLAN500" with color 256:
# Entities on layer "EPLAN504" with color 256:
# Entities on layer "EPLAN502" with color 256:
# Entities on layer "EPLAN503" with color 256:
# Entities on layer "EPLAN408" with color 7:
# Entities on layer "EPLAN400" with color 7:
# Entities on layer "EPLAN420" with color 1:
#  TEXT(#108F)
#  TEXT(#11B0)
# ----------------------------------------
